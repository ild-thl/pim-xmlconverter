# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import sys
import re
from os.path import exists
import pdfplumber
import os
import xmltodict

base_url = 'https://www.th-luebeck.de'

# %%
class Program:
    def __init__(self, name, identifier, qualification, parent, url = ''):
        self.name = name
        self.identifier = identifier
        self.qualification = qualification
        self.parent = parent
        self.url = url
    

    def to_dict(self):
        return {
            'Studiengang': '',
            'Name': self.name,
            'Identifier': self.identifier,
            'Bildungsstufe': self.qualification, # UNKNOWN, BACHELOR, MASTER, PH_D
            'Organisationseinheit': self.parent
        }
        

class Faculty:
    def __init__(self, name, identifier, abbreviation, parent = '', url = ''):
        self.name = name
        self.identifier = identifier
        self.abbreviation = abbreviation
        self.parent = parent
        self.url = url
    

    def to_dict(self):
        return {
            'OE': '',
            'Name': self.name,
            'Identifier': self.identifier,
            'abbreviation': self.abbreviation,
            'parent': self.parent
        }
        

class Stupo:
    def __init__(self, name, identifier, parent, desc = '', url = '', duration = ''):
        self.name = name
        self.identifier = identifier
        self.desc = desc
        self.url = url
        self.parent = parent
        self.url = url
        self.duration = duration
    

    def to_dict(self):
        return {
            'Stupo': '',
            'Name': self.name,
            'Identifier': self.identifier,
            'Beschreibungstext': self.desc,
            'Beschreibungslink': self.url,
            'parent': self.parent,
            'Dauer': self.duration
        }
        

class Programarea:
    def __init__(self, name, identifier, parent, freeChoice = False):
        self.name = name
        self.identifier = identifier
        self.parent = parent
        self.freeChoice = freeChoice
    

    def to_dict(self):
        return {
            'Studiengangsbereich': '',
            'Name': self.name,
            'Identifier': self.identifier,
            'freie Wahl': self.freeChoice,
            'parent': self.parent
        }
        

class Modul:
    def __init__(self, name, identifier, parent, desc = '', url = '', duration = '', credits = ''):
        self.name = name
        self.identifier = identifier
        self.desc = desc
        self.url = url
        self.parent = parent
        self.url = url
        self.duration = duration
        self.credits = credits
    

    def to_dict(self):
        return {
            'Modul': '',
            'Name': self.name,
            'identifier': self.identifier,
            'Beschreibungstext': self.desc,
            'Beschreibungslink': self.url,
            'parent': self.parent,
            'Dauer': self.duration,
            'credits': self.credits
        }

def parseQualification(qualification):
    qualification = qualification.lower()
    if 'bachelor' in qualification:
        return 'BACHELOR'
    elif 'master' in qualification:
        return 'MASTER'


class Modulhandbuch:

    def __init__(self):
        self.faculties = []
        self.programs = []
        self.stupos = []
        self.programareas = []
        self.modules = []


    def addFaculty(self, name, identifier, abbreviation, parent = '', url = ''):
        faculty = Faculty(name, identifier, abbreviation, parent, url)
        self.faculties.append(faculty)
        return faculty


    def getFaculty(self, identifier):
        if identifier == '':
            return None
            
        for faculty in self.faculties:
            if faculty.identifier == identifier:
                return faculty


    def addProgram(self, name, identifier, qualification, parent, url = ''):
        program = Program(name, identifier, qualification, parent, url)
        self.programs.append(program)
        return program


    def getProgram(self, name, qualification):
        if name == '' and qualification == '':
            return None
            
        for program in self.programs:
            if program.name == name and program.qualification == qualification:
                return program


    def addStupo(self, name, identifier, parent, desc = '', url = '', duration = ''):
        stupo = Stupo(name, identifier, parent, desc, url, duration)
        self.stupos.append(stupo)
        return stupo


    def getStupo(self, parent=''):
        if parent == '':
            return None
        
        for stupo in self.stupos:
            if stupo.parent == parent:
                return stupo


    def addProgramarea(self, name, identifier, parent, freeChoice = False):
        programarea = Programarea(name, identifier, parent, freeChoice)
        self.programareas.append(programarea)
        return programarea


    def getProgramarea(self, identifier):
        if identifier == '':
            return None

        for programarea in self.programareas:
            if programarea.identifier == identifier:
                return programarea


    def addModul(self, name, identifier, parent, desc = '', url = '', duration = '', credits=''):
        modul = Modul(name, identifier, parent, desc, url, duration, credits)
        self.modules.append(modul)
        return modul
    
    def updateModul(self, index, name, identifier, parent, desc = '', url = '', duration = '', credits=''):
        if index not in range(len(self.modules)):
            return
        
        modul = Modul(name, identifier, parent, desc, url, duration, credits)
        self.modules[index] = modul
        return modul


    def getModul(self, identifier='', name='', childof=''):
        if name == '' and identifier == '':
            return None
        

        for i in range(len(self.modules)):
            modul = self.modules[i]
            if identifier:
                if modul.identifier != identifier:
                    continue
            else:
                if modul.name != name:
                    continue
            
            if not childof:
                continue

            if  childof not in modul.identifier:
                continue

            return modul


    def getModulIndex(self, identifier='', name='', childof=''):
        if name == '' and identifier == '':
            return None
        

        for i in range(len(self.modules)):
            modul = self.modules[i]
            if identifier:
                if modul.identifier != identifier:
                    continue
            else:
                if modul.name != name:
                    continue
            
            if childof and childof not in modul.identifier:
                continue

            return i
        
        print(identifier, name, childof)

    
    def getModulChildren(self, parentid):
        children = []

        for i in range(len(self.modules)):
            modul = self.modules[i]

            if parentid in modul.identifier and modul.identifier != parentid:
                children.append(modul)
        
        return children


    def toCsv(self):
        dict = [faculty.to_dict() for faculty in self.faculties]
        df = pd.DataFrame.from_dict(dict)
        df.to_csv('output/csv/faculties.csv', index = False, header=True)

        dict = [program.to_dict() for program in self.programs]
        df = pd.DataFrame.from_dict(dict)
        df.to_csv('output/csv/programs.csv', index = False, header=True)

        dict = [stupo.to_dict() for stupo in self.stupos]
        df = pd.DataFrame.from_dict(dict)
        df.to_csv('output/csv/stupos.csv', index = False, header=True)

        dict = [programarea.to_dict() for programarea in self.programareas]
        df = pd.DataFrame.from_dict(dict)
        df.to_csv('output/csv/programareas.csv', index = False, header=True)

        dict = [modul.to_dict() for modul in self.modules]
        df = pd.DataFrame.from_dict(dict)
        df.to_csv('output/csv/modules.csv', index = False, header=True)

# %%
modulhandbuch = Modulhandbuch()

# %%
# Create Faculties. This is manageable and dosn'nt change often. Therefore it is hardcoded.
modulhandbuch.addFaculty('Angewandte Naturwissenschaften', '11', 'AN', url='https://www.th-luebeck.de/hochschule/fachbereich-angewandte-naturwissenschaften/studiengaenge/')
modulhandbuch.addFaculty('Bauwesen', '12', 'BAU', url='https://www.th-luebeck.de/hochschule/fachbereich-bauwesen/studiengaenge/')
modulhandbuch.addFaculty('Elektrotechnik und Informatik', '13', 'EI', url='https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/')
modulhandbuch.addFaculty('Maschinenbau und Wirtschaft', '14', 'MW', url='https://www.th-luebeck.de/hochschule/fachbereich-maschinenbau-und-wirtschaft/studiengaenge/')

# %%
abbreviations = []

# Creates an abbreviation based on a given string for use as an identifier.
def getAbbreviation(name, qualification = '', check_duplicate=True, word_length = 3, max_words = 5):
    abbr = ''
    split = re.split(' |-', name)
    counter = 1
    while True:
        for i in range(min(len(split), max_words)):
            word = split[i]
            word = word.upper()
            # word = re.sub(r'\s', '', word)
            if len(word) <= 1 or (len(word) <= 3 and word != split[i]) or split[i][0] == '(':
                continue
            
        
            if i != 0:
                abbr +='-'

            abbr += word[:word_length]

        if qualification == 'BACHELOR':
            abbr += '-BA'
        elif qualification == 'MASTER':
            abbr += '-MA'
        
        if not check_duplicate:
            break

        if counter > 1:
            abbr += '-' + str(counter)

        if abbr not in abbreviations:
            abbreviations.append(abbr)
            break
        if word_length > 3:
            counter += 1
        else:
            word_length += 1
        
        print('Duplicate abbreviation: ' + abbr)
    
    return abbr

# %%
program_blacklist = ['Wirtschaftsingenieur Lebensmittelindustrie']


def scrapePrograms():
    for faculty in modulhandbuch.faculties:
        r = requests.get(faculty.url)
        
        # Check status code for response received
        if r.status_code not in range(200, 300):
            print('Status ' + str(r.status_code) + ' at  ' + faculty.url + '/weiteres')
            continue

        # Parsing the HTML
        soup = bs(r.content, 'html.parser')

        # Finding table of studyprogrammes
        main = soup.find(id='main')
        table = soup.find('table')

        # find all the anchor tags with 'href'
        for link in table.find_all('a'):
            qualification = parseQualification(link.parent.parent.parent.findAll('td')[2].find('abbr').get('title'))

            text = link.text
            name = ''
            match = re.search(r'(.+) \((.+)\)', text)
            if match:
                name = match.group(1)
                identifier = match.group(2)
            else:
                name = text
                identifier = getAbbreviation(name, qualification)

            if identifier.upper() != identifier:
                identifier = getAbbreviation(name, qualification)

            if name in program_blacklist:
                continue
            
            parent = faculty.identifier
            url = base_url + link.get('href')

            modulhandbuch.addProgram(name, faculty.abbreviation + '_' + identifier, qualification, parent, url)


scrapePrograms()
# Out:
# Duplicate abbreviation: WIR-LEB-BA

# %%
def scrapeDuration(pdf):
    for page in pdf.pages:
        text = page.extract_text()
        split = text.split('\n')
        for i in range(len(split)):
            line = split[i]
            match = re.match(r'.*Die Regelstudienzeit beträgt (.+) .*Semester.', line, re.IGNORECASE)
            if match:
                dur = match.group(1)
                if dur == 'ein' or dur == '1':
                    duration = '6 Monate'
                elif dur == 'zwei' or dur == '2':
                    duration = '12 Monate'
                elif dur == 'drei' or dur == '3':
                    duration = '18 Monate'
                elif dur == 'vier' or dur == '4':
                    duration = '24 Monate'
                elif dur == 'fünf' or dur == '5':
                    duration = '30 Monate'
                elif dur == 'sechs' or dur == '6':
                    duration = '36 Monate'
                elif dur == 'sieben' or dur == '7':
                    duration = '42 Monate'
                elif dur == 'acht' or dur == '8':
                    duration = '48 Monate'
                return duration
            else:
                match = re.match(r'.*Die Regelstudienzeit beträgt (.+) .*jahr', line, re.IGNORECASE)
                if match:
                    dur = match.group(1)
                    if dur == 'ein' or dur == '1':
                        duration = '12 Monate'
                    elif dur == 'zwei' or dur == '2':
                        duration = '24 Monate'
                    elif dur == 'drei' or dur == '3':
                        duration = '36 Monate'
                    elif dur == 'vier' or dur == '4':
                        duration = '48 Monate'
                    return duration
    
    return ''

# %%
def scrapeStupos():
    for program in modulhandbuch.programs:
        # if program.parent != '12':
        if program.parent != '13' and program.parent != '12':
            # print('Skipped: ' + program.identifier)
            continue

        faculty = modulhandbuch.getFaculty(identifier=program.parent)
        if faculty == None:
            print('Couldnt find faculy for: ' + program.parent)
            return

        dirname = 'output/pdf/' + faculty.abbreviation + '/stupos/' + program.identifier
        if not os.path.exists(dirname):
            os.makedirs(dirname)
        
        r = requests.get(program.url)
    
        # Check status code for response received
        if r.status_code not in range(200, 300):
            print('Status ' + str(r.status_code) + ' at  ' + program.url)
            continue

        # Parsing the HTML
        soup = bs(r.content, 'html.parser')

        stupo_links = [ 
            link['href'] for link in soup.find_all('a', href=True) if re.match(r'.*Satzungen%20zu%20Studium%20und%20Prfungen.*_(S)?PO(_\d+)?\.pdf$', link['href'])
        ]

        url = ''
        desc = ''
        duration = ''
        
        if stupo_links or len(stupo_links) >= 1:
            url = stupo_links[0]
            date = ''
            match = re.match(r'.*Satzungen%20zu%20Studium%20und%20Prfungen.*_(S)?PO_(\d+)\.pdf$', url)
            if match:
                date = match.group(2)

            
            filename = dirname + '/SPO_' + program.identifier + date + '.pdf'
            if not exists(filename):
                # Download stupo pdf.
                pdf_response = requests.get(url)
                with open(filename, 'wb') as f:
                    f.write(pdf_response.content)

            with pdfplumber.open(filename) as pdf:
                page = pdf.pages[0]
                text = page.extract_text()
                split = text.split('\n')
                # print(text)
                desc_index = None
                for i in range(len(split)):
                    line = split[i]
                    if date == '':
                        match = re.match(r'Vom \d+\. \w+ (\d{4})', line)
                        if match:
                            date = match.group(1)

                    if desc_index == None:
                        if re.sub(r'\s', '', line) == '§2' and 'Studiengang' in split[i+1]:
                            desc_index = i+2
                            break
                
                
                if desc_index:
                    for i in range(desc_index, len(split)):
                        if re.sub(r'\s', '', split[i]) == '§3':
                            desc = desc.strip()
                            break

                        desc += split[i] + '\n'
                    

                duration = scrapeDuration(pdf)

        # Handle multiple diffrent SPO pdfs. Choose the latest SPO.
        # if len(stupo_links) > 1:
        #     dates = []
        #     for link in stupo_links:
        #         match = re.match(r'.*Satzungen%20zu%20Studium%20und%20Prfungen.*SPO_(\d+)\.pdf$', url)
        #         if match:
        #             dates.append(match.group(1))
        #         else:
        #             dates.append(0)
            
        #     print(dates)

        not_found = ''
        if not url:
            not_found += 'URL '
        if not desc:
            not_found += 'Description '
        if not duration:
            not_found += 'Duration '

        if not_found != '':
            print(not_found + 'not found for: ' + program.identifier)

        stupo_identifier = program.identifier + date
        stupo_name = program.name
        if program.qualification == 'BACHELOR':
            stupo_name += ' Bachelor'
        elif program.qualification == 'MASTER':
            stupo_name += ' Master'

        modulhandbuch.addStupo(stupo_name + ' SPO ' + date, stupo_identifier, program.identifier, url=url, desc=desc, duration=duration)
        modulhandbuch.addProgramarea(stupo_name + ' Pflichtmodule', stupo_identifier + '_PF', stupo_identifier, freeChoice=False)
        modulhandbuch.addProgramarea(stupo_name + ' Wahlpflichtmodule', stupo_identifier + '_WAPF', stupo_identifier, freeChoice=True)
        modulhandbuch.addProgramarea(stupo_name + ' Wahlmodule', stupo_identifier + '_WA', stupo_identifier, freeChoice=True)


scrapeStupos()

# %%
def scrapeModulhandbuchPDF_v1(pdf, url, stupo, en=False):
    def scrapeName(split, en=False):
        if en:
            match = re.search(r'1. *(.*) *', split[4])
            if match:
                return match.group(1).strip()
        match = re.search(r'1. *(.*) {2,}.*$', split[4])
        if match:
            return match.group(1).strip()
        
        return ''

    def scrapeModulart(split, en=False):
        if en:
            match = re.search(r'Module type *(.*) *Self-study hours', split[5])
            if match:
                return match.group(1).strip()

        match = re.search(r'Modulart *(\w*) *Eigenstudiumsstunden', split[5])
        if match:
            return match.group(1).strip()
        
        return ''

    def scrapeAbbreviation(split, en=False):
        if en:
            match = re.search(r'Module abbreviation *(.*) *Seminar', split[15])
            if match:
                return match.group(1).strip()
        
        match = re.search(r'Modulkürzel *(.*) *Seminar', split[15])
        if match:
            return match.group(1).strip()
        
        return ''

    def scrapeCreditsAndDuration(split, en=False):
        if en:
            match = re.search(r'2. ECTS *(\d+([\.,]\d?)?) *CP 3. Workload (\d+) h', split[3])
            if match:
                return match.group(1).strip(), match.group(3).strip() + ' Stunden'
        match = re.search(r'2. ECTS-Leistungspunkte *(\d+([\.,]\d?)?) *LP 3. Arbeitsaufwand (\d+) h', split[3])
        if match:
            return match.group(1).strip(), match.group(3).strip() + ' Stunden'
        
        return '', ''

    def scrapeDescription(split, en=False):
        desc = ''
        kenntnisse_start = False
        kenntnisse = ''
        fertigkeiten_start = False
        fertigkeiten = ''
        kompetenzen_start = False
        kompetenzen = ''

        for line in split:
            if line.startswith('8. Kenntnisse') or line.startswith('8. Knowledge'):
                kenntnisse_start = True
                line = re.sub(r'8\. (Kenntnisse|Knowledge) *', '', line)
            elif line.startswith('9. Fertigkeiten') or line.startswith('9. Skills'):
                kenntnisse_start = False
                fertigkeiten_start = True
                line = re.sub(r'9\. (Fertigkeiten|Skills) *', '', line)
            elif line.startswith('10. Kompetenzen') or line.startswith('10. Learning outcomes'):
                fertigkeiten_start = False
                kompetenzen_start = True
                line = re.sub(r'10\. (Kompetenzen|Learning outcomes) *', '', line)
        
            if kenntnisse_start:
                kenntnisse += '\n' + line
            elif fertigkeiten_start:
                fertigkeiten += '\n' + line
            elif kompetenzen_start:
                kompetenzen += '\n' + line

        kenntnisse = cleanText(kenntnisse)
        fertigkeiten = cleanText(fertigkeiten)
        kompetenzen = cleanText(kompetenzen)
        
        if en:
            if kenntnisse:
                desc += 'Knowledge\n' + kenntnisse + '\n\n'
            if fertigkeiten:
                desc += 'Skills\n' + fertigkeiten + '\n\n'
            if kompetenzen:
                desc += 'Learning outcomes\n' + kompetenzen
        else:
            if kenntnisse:
                desc += 'Kenntnisse\n' + kenntnisse + '\n\n'
            if fertigkeiten:
                desc += 'Fertigkeiten\n' + fertigkeiten + '\n\n'
            if kompetenzen:
                desc += 'Kompetenzen\n' + kompetenzen

        return desc
    
    def scrapeLehrveranstaltungen(split, parent, en=False):
        if en:
            if 'Lecture x' in split[11]:
                modulhandbuch.addModul(parent.name + ' (Lecture)', parent.identifier + '_V', parent.identifier, '', parent.url, '', '')
            if 'Excercise x' in split[12]:
                modulhandbuch.addModul(parent.name + ' (Excercise)', parent.identifier + '_Ü', parent.identifier, '', parent.url, '', '')
            if 'Practical training x' in split[13]:
                modulhandbuch.addModul(parent.name + ' (Practical training)', parent.identifier + '_Pr', parent.identifier, '', parent.url, '', '')
            if 'Project work x' in split[14]:
                modulhandbuch.addModul(parent.name + ' (Project work)', parent.identifier + '_Pj', parent.identifier, '', parent.url, '', '')
            if 'Seminar x' in split[15]:
                modulhandbuch.addModul(parent.name + ' (Seminar)', parent.identifier + '_S', parent.identifier, '', parent.url, '', '')
            if 'Excursion x' in split[16]:
                modulhandbuch.addModul(parent.name + ' (Excursion)', parent.identifier + '_E', parent.identifier, '', parent.url, '', '')
        else:
            if 'Vorlesung (V) x' in split[11]:
                modulhandbuch.addModul(parent.name + ' (Vorlesung)', parent.identifier + '_V', parent.identifier, '', parent.url, '', '')
            if 'Übung (Ü) x' in split[12]:
                modulhandbuch.addModul(parent.name + ' (Übung)', parent.identifier + '_Ü', parent.identifier, '', parent.url, '', '')
            if 'Praktikum (PR) x' in split[13]:
                modulhandbuch.addModul(parent.name + ' (Praktikum)', parent.identifier + '_Pr', parent.identifier, '', parent.url, '', '')
            if 'Projekt (Pj) x' in split[14]:
                modulhandbuch.addModul(parent.name + ' (Projekt)', parent.identifier + '_Pj', parent.identifier, '', parent.url, '', '')
            if 'Seminar (S) x' in split[15]:
                modulhandbuch.addModul(parent.name + ' (Seminar)', parent.identifier + '_S', parent.identifier, '', parent.url, '', '')
            if 'Exkursion (E) x' in split[16]:
                modulhandbuch.addModul(parent.name + ' (Exkursion)', parent.identifier + '_E', parent.identifier, '', parent.url, '', '')


    programarea_pf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_PF')
    if not programarea_pf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_PF')
        return
    programarea_wapf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WAPF')
    if not programarea_wapf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WAPF')
        return
    programarea_wa = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WA')
    if not programarea_wa:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WA')
        return

    pages_count = len(pdf.pages)
    
    for i in range(pages_count):
        page = pdf.pages[i]
        layout_text = page.extract_text(layout=True)
        layout_split = layout_text.split('\n')
        text = page.extract_text(layout=False)
        split = text.split('\n')
        # first_5_lines = ' '.join(split[:5])
        # print(split)

        name = scrapeName(layout_split, en)
        if not name:
            print('Couldnt get name of module in ' + stupo.name)
            return
        modulart = scrapeModulart(split, en)
        if not modulart:
            print('Couldnt get Verpflichtungsgrad of ' + name)
            return
        if modulart == 'Pflichtmodul' or modulart == 'Compulsory':
            parent = programarea_pf
        elif modulart == 'Vertiefungsmodul' or modulart == 'Elective':
            parent = programarea_wapf
        else:
            print('Unkwown verpflichtungsgrad "' + modulart + '" of ' + name)
            continue

        abbreviation = scrapeAbbreviation(split, en)
        if not abbreviation:
            abbreviation = getAbbreviation(name, check_duplicate=False, word_length=2, max_words=2)
            
        identifier = parent.identifier + '_' + abbreviation

        desc = scrapeDescription(split, en)
        credits, duration = scrapeCreditsAndDuration(split, en)

        # print('\nname: ')
        # print(name)
        # print('\nkürzel: ')
        # print(abbreviation)
        # print('\nidentifier: ')
        # print(identifier)
        # print('\ndesc: ')
        # print(desc)
        # print('\ncredits: ')
        # print(credits)
        # print('\nduration: ')
        # print(duration)
        modul = modulhandbuch.addModul(name, identifier, parent.identifier, desc, url, '', credits)
        scrapeLehrveranstaltungen(split, modul, en)

# %%
def cleanText(text):
    if not text:
        return ''
 
    text = re.sub(r' *\n *(\d+(\.(\d+)?)*) +(.+)', r'<br>\1 \4', text)
    text = re.sub(r'\n+', ' ', text)
    text = re.sub(r'\* +', '\n- ', text)
    text = re.sub(r'• +', '\n- ', text)
    text = re.sub(r' +', ' ', text)
    text = re.sub(r'<br>', '\n', text)
    return text.strip()


def scrapeModulhandbuchPDF_v2(pdf, url, stupo, en=False, version=1):
    def scrapeName(text, en = False, version=1):
        if en:
            match = re.search(r'Module: *(.*) *Level', text)
            if match:
                return match.group(1).strip()
            else:
                match = re.search(r'Module Course: *(.*) *\(of Module:', text)
                if match:
                    return match.group(1).strip()
        
        if version == 2:
            match = re.search(r'Modulname: *(.*) *Modulnummer', text)
            if match:
                return match.group(1).strip()
            else:
                match = re.search(r'Lehrveranstaltungsname.*: *(.*) *Lehrveranstaltungsnr.', text)
                if match:
                    return match.group(1).strip()
        
        match = re.search(r'Modul: *(.*) *Niveau', text)
        if match:
            return match.group(1).strip()
        else:
            match = re.search(r'Lehrveranstaltung: *(.*) *\(zu Modul:', text)
            if match:
                return match.group(1).strip()
        
        return ''

    def scrapeParentName(text, en = False):
        if en:
            match = re.search(r'\(of Module: *(.*) *\) *Course Type', text)
            if match:
                return match.group(1).strip()
        
        match = re.search(r'\(zu Modul: *(.*) *\) *Lehrveranstaltungsart', text)
        if match:
            return match.group(1).strip()
        
        return ''
        
    def scrapeLehrveranstaltungsart(text, en = False):
        if en:
            match = re.search(r'Course Type *(.*) *Form of Learning', text)
            if match:
                return match.group(1).strip()
        
        match = re.search(r'Lehrveranstaltungsart *(.*) *Lernform', text)
        if match:
            return match.group(1).strip()
        
        return ''
        
    def scrapeAbbreviation(text, en = False):
        if en:
            match = re.search(r'Short Name *(.*) *Responsible Lecturers', text)
            if match:
                return match.group(1).strip().replace(' ', '-')

        match = re.search(r'ürzel *(.*) *Modulname englisch', text)
        if match:
            return match.group(1).strip().replace(' ', '-')
        
        return ''
        
    def scrapeVerpflichtungsgrad(text, en = False):
        if en:
            match = re.search(r'Compulsory/elective *(.*) *ECTS', text)
            if match:
                return match.group(1).strip()
        
        match = re.search(r'Verpflichtungsgrad *(.*) *ECTS', text)
        if match:
            return match.group(1).strip()
        
        return ''
        
    def scrapeDuration(text, en = False):
        if en:    
            match = re.search(r'Workload \(hours\) *(\d+) *(Frequency|Teaching Language)', text)
            if match:
                return match.group(1).strip() + ' Stunden'
            
        match = re.search(r'Arbeitsaufwand in Stunden *(\d+) *(Angebotshäufigkeit|Lehrsprache)', text)
        if match:
            return match.group(1).strip() + ' Stunden'
        
        return ''
        
    def scrapeCredits(text, en = False):
        if en:
            match = re.search(r'ECTS Credit Points *(\d+([\.,]\d?)?) *(Semester of Studies|Participation Limit)', text)
            if match:
                return match.group(1).strip()
        
        match = re.search(r'ECTS-Leistungspunkte *(\d+([\.,]\d?)?) *(Fachsemester|Teilnahmebeschränkung)', text)
        if match:
            return match.group(1).strip()
        
        return ''

    def scrapeLernergebnisse(split, en = False):
        start = False
        lernergebnisse = ''

        for line in split:
            if line.startswith('Lernergebnisse') or line.startswith('Learning Outcomes'):
                start = True
                line = re.sub(r'(Lernergebnisse|Learning Outcomes)', '', line)
            elif line.startswith('Teilnahmevoraussetzungen') or line.startswith('Participation Prerequisites'):
                break
        
            if start:
                lernergebnisse += '\n' + line

        lernergebnisse = cleanText(lernergebnisse)
        if lernergebnisse:
            if en:
                lernergebnisse = 'Learning Outcomes\n' + lernergebnisse
            else:
                lernergebnisse = 'Lernergebnisse\n' + lernergebnisse
        
        return lernergebnisse

    def scrapeLehrinhalte(split, en = False):
        start = False
        lehrinhalte = ''

        for line in split:
            if line.startswith('Lehrinhalte') or line.startswith('Contents'):
                start = True
                line = re.sub(r'(Lehrinhalte|Contents)', '', line)
            elif line.startswith('Literatur'):
                break
        
            if start:
                lehrinhalte += '\n' + line

        lehrinhalte = cleanText(lehrinhalte)
        if lehrinhalte:
            if en:
                lehrinhalte = 'Contents\n' + lehrinhalte
            else:
                lehrinhalte = 'Lehrinhalte\n' + lehrinhalte
        return lehrinhalte
        
    def scrapeDescription(split, en = False):
        lernergebnisse = scrapeLernergebnisse(split, en)
        lehrinhalte = scrapeLehrinhalte(split, en)

        if lernergebnisse and lehrinhalte:
            return lernergebnisse + '\n\n' + lehrinhalte
        elif lernergebnisse:
            return lernergebnisse
        elif lehrinhalte:
            return lehrinhalte
        return ''

    def isModul(text):
        if version == 2:
            return 'Modulname:' in text
        else:
            if en:
                return 'Module:' in text
            else:
                return 'Modul:' in text or 'Module:' in text

    def isLehrveranstaltung(text):
        if version == 2:
            return 'Lehrveranstaltung(en) des Moduls' in text
        else:
            if en:
                return text.startswith('Module Course:')
            else:
                return text.startswith('Lehrveranstaltung:')
    

    programarea_pf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_PF')
    if not programarea_pf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_PF')
        return
    programarea_wapf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WAPF')
    if not programarea_wapf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WAPF')
        return
    programarea_wa = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WA')
    if not programarea_wa:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WA')
        return

    pages_count = len(pdf.pages)

    last_modul_name = ''
    
    for i in range(pages_count):
        page = pdf.pages[i]
        text = page.extract_text(layout=False)
        split = text.split('\n')

        first_5_lines = ' '.join(split[:5])

        is_modul = isModul(first_5_lines)

        if not is_modul:
            continue
        
        first_20_lines = ' '.join(split[:20])
        
        is_lehrveranstaltung = isLehrveranstaltung(first_5_lines)

        if is_lehrveranstaltung:
            if i+1 < pages_count:
                next_text = pdf.pages[i+1].extract_text(layout=False)
                next_split = next_text.split('\n')
                next_5_lines = ' '.join(next_split[:5])

                if not isModul(next_5_lines):
                    text += '\n' + next_text
                    if version == 2:
                        split = split[:len(split)-3] + next_split
                    else:
                        split = split[:len(split)-1] + next_split
        else:
            if i+1 < pages_count:
                next_text = pdf.pages[i+1].extract_text(layout=False)
                next_split = next_text.split('\n')
                next_5_lines = ' '.join(next_split[:5])

                if not isModul(next_5_lines):
                    text += '\n' + next_text
                    if version == 2:
                        split = split[:len(split)-3] + next_split
                    else:
                        split = split[:len(split)-1] + next_split
        
        name = scrapeName(first_5_lines, en, version)
        if not name:
            print('Couldnt get name of module in programarea ' + stupo.name)
            print(first_5_lines)
            return
        if is_lehrveranstaltung:
            parent_name = ''
            if version == 2:
                if last_modul_name:
                    parent_name = last_modul_name
            else:
                parent_name = scrapeParentName(first_5_lines, en)
            
            if not parent_name:
                print('Couldnt find parent name of: ' + name)
                continue

            parent = modulhandbuch.getModul(name=parent_name, childof=stupo.identifier)
            if not parent:
                print('Couldnt find parent modul with name: ' + parent_name)
                continue
            
            lehrveranstaltungsart = scrapeLehrveranstaltungsart(first_5_lines, en)
            if lehrveranstaltungsart == '':
                identifier = parent.identifier + '_' + getAbbreviation(name, check_duplicate=False, word_length=2, max_words=2)
            elif lehrveranstaltungsart == 'Vorlesung' or lehrveranstaltungsart == 'Lecture':
                identifier = parent.identifier + '_V'
            elif lehrveranstaltungsart == 'Projekt' or lehrveranstaltungsart == 'Project Work':
                identifier = parent.identifier + '_Pj'
            elif lehrveranstaltungsart == 'Praktikum' or lehrveranstaltungsart == 'Practical Training':
                identifier = parent.identifier + '_Pr'
            elif lehrveranstaltungsart == 'Übung' or lehrveranstaltungsart == 'Exercise':
                identifier = parent.identifier + '_Ü'
            elif lehrveranstaltungsart == 'Seminar' or lehrveranstaltungsart == 'Seminar':
                identifier = parent.identifier + '_S'
            elif lehrveranstaltungsart == 'Exkursion' or lehrveranstaltungsart == 'Excursion':
                identifier = parent.identifier + '_Ex'
            elif lehrveranstaltungsart == 'Online-':
                identifier = parent.identifier + '_O'
                lehrveranstaltungsart = 'Online'
            else:
                print('Unkwon Lehrveranstaltungsart "' + lehrveranstaltungsart + '" of ' + name)
                print(text)
                continue
            
            if name == parent.name:
                name += ' (' + lehrveranstaltungsart + ')'
        else:
            last_modul_name = name
            verpflichtungsgrad = scrapeVerpflichtungsgrad(first_20_lines, en)
            if not verpflichtungsgrad:
                print('Couldnt get Verpflichtungsgrad of ' + name)
                continue
            if verpflichtungsgrad == 'Pflicht' or verpflichtungsgrad == 'Compulsory':
                parent = programarea_pf
            elif verpflichtungsgrad == 'Wahlpflicht' or verpflichtungsgrad == 'Compulsory elective':
                parent = programarea_wapf
            elif verpflichtungsgrad == 'Wahl' or verpflichtungsgrad == 'Elective':
                parent = programarea_wa
            elif verpflichtungsgrad == '(Nicht festgelegt)':
                if '. Fachsemester' in first_5_lines:
                    parent = programarea_pf
                else:
                    parent = programarea_wa
            else:
                print('Unkwown verpflichtungsgrad "' + verpflichtungsgrad + '" of ' + name)
                continue
            abbreviation = scrapeAbbreviation(first_5_lines, en)
            if not abbreviation:
                abbreviation = getAbbreviation(name, check_duplicate=False, word_length=2, max_words=2)
            
            identifier = parent.identifier + '_' + abbreviation

        desc = scrapeDescription(split, en)
        # duration = scrapeDuration(first_20_lines, en)
        credits = scrapeCredits(first_20_lines, en)

        # if en:
        #     print('\nname: ')
        #     print(name)
        #     print('\nidentifier: ')
        #     print(identifier)
        #     print('\ndesc: ')
        #     print(desc)
        #     print('\nduration: ')
        #     print(duration)
        #     print('\ncredits: ')
        #     print(credits)
        #     print('\n\n')
        modulhandbuch.addModul(name, identifier, parent.identifier, desc, url, '', credits)

# %%
def scrapeModulhandbuchPDF_v3(pdf, url, stupo, en=False):
    def scrapeName(split, en = False):
        match = re.search(r'\d* *(.*)', split[0])
        if match:
            return match.group(1).strip()
        
        return ''
        
    def scrapeVerpflichtungsgrad(text, en = False):
        # if en:
        #     match = re.search(r'Compulsory/elective *(.*)', split[5])
        #     if match:
        #         return match.group(1).strip()
        
        match = re.search(r'Pflicht/ Wahlpflicht *(.*) *\n', text)
        if match:
            return match.group(1).strip()
        
        return ''
        
    def scrapeDuration(text, en = False):
        # if en:    
        #     match = re.search(r'Workload \(hours\) *(\d+) *(Frequency|Teaching Language)', text)
        #     if match:
        #         return match.group(1).strip() + ' Stunden'
        
        duration = 0
        match = re.search(r'(Arbeitsaufwand )?Selbststudium: *(ca\. *)?(\d+((,|.)\d+)?) *h', text)
        if match:
            duration += float(match.group(3).strip().replace(',', '.'))
        match = re.search(r'Betreutes Lernen: *(\d+) *h', text)
        if match:
            duration += float(match.group(1).strip().replace(',', '.'))
        match = re.search(r'Vorbereitung PVL: *(\d+) *h', text)
        if match:
            duration += float(match.group(1).strip().replace(',', '.'))
        
        return str(duration).replace('.', ',').replace(',0', '') + ' Stunden'
    
    def scrapeCredits(text, en = False):
        # if en:
        #     match = re.search(r'ECTS Credit Points *(\d+([\.,]\d?)?) *(Semester of Studies|Participation Limit)', text)
        #     if match:
        #         return match.group(1).strip()
        
        match = re.search(r'Credit Points *(.*) *\n', text)
        if match:
            return match.group(1).strip()
        
        return ''

    def scrapeLernergebnisse(split, en = False):
        start = False
        lernergebnisse = ''

        for line in split:
            if line.startswith('Lernergebnisse'):
                start = True
                line = re.sub(r'(Lernergebnisse)', '', line)
            elif line.startswith('Prüfungsvorleistung'):
                break
        
            if start:
                lernergebnisse += '\n' + line

        lernergebnisse = cleanText(lernergebnisse)
        if lernergebnisse:
            if en:
                lernergebnisse = 'Learning Outcomes\n' + lernergebnisse
            else:
                lernergebnisse = 'Lernergebnisse\n' + lernergebnisse
        
        return lernergebnisse

    def scrapeLehrinhalte(split, en = False):
        start = False
        lehrinhalte = ''

        for line in split:
            if line.startswith('Studieninhalte'):
                start = True
                line = re.sub(r'(Studieninhalte)', '', line)
            # elif line.startswith('Literatur'):
            #     break
        
            if start:
                lehrinhalte += '\n' + line

        lehrinhalte = cleanText(lehrinhalte)
        if lehrinhalte:
            if en:
                lehrinhalte = 'Contents\n' + lehrinhalte
            else:
                lehrinhalte = 'Studieninhalte\n' + lehrinhalte
        return lehrinhalte
        
    def scrapeDescription(split, en = False):
        lernergebnisse = scrapeLernergebnisse(split, en)
        lehrinhalte = scrapeLehrinhalte(split, en)

        if lernergebnisse and lehrinhalte:
            return lernergebnisse + '\n\n' + lehrinhalte
        elif lernergebnisse:
            return lernergebnisse
        elif lehrinhalte:
            return lehrinhalte
        return ''

    def isLehrveranstaltung(text):
        if en:
            return text.startswith('Module Course:')
        else:
            return text.startswith('Lehrveranstaltung:')
    

    programarea_pf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_PF')
    if not programarea_pf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_PF')
        return
    programarea_wapf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WAPF')
    if not programarea_wapf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WAPF')
        return
    programarea_wa = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WA')
    if not programarea_wa:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WA')
        return

    pages_count = len(pdf.pages)

    last_modul_name = ''

    text = ''
    split = []
    
    for i in range(pages_count):
        page = pdf.pages[i]
        thistext = page.extract_text(layout=False)
        text += '\n' + thistext
        thissplit = thistext.split('\n')
        split += thissplit[1:len(thissplit)-1]


    first_8_lines = '\n'.join(split[:8])
    first_20_lines = '\n'.join(split[:20])
        
    name = scrapeName(split, en)
    if not name:
        print('Couldnt get name of module in programarea ' + stupo.name)
        print(split)
        return
    
    verpflichtungsgrad = scrapeVerpflichtungsgrad(first_8_lines, en)
    if not verpflichtungsgrad:
        print('Couldnt get Verpflichtungsgrad of ' + name)
        print(first_8_lines)
        return
    
    if verpflichtungsgrad == 'Pflicht' or verpflichtungsgrad == 'Compulsory':
        parent = programarea_pf
    elif verpflichtungsgrad == 'Wahlpflicht' or verpflichtungsgrad == 'Compulsory elective':
        parent = programarea_wapf
    elif verpflichtungsgrad == 'Wahl' or verpflichtungsgrad == 'Elective':
        parent = programarea_wa
    elif verpflichtungsgrad == '(Nicht festgelegt)':
        if '. Fachsemester' in first_8_lines:
            parent = programarea_pf
        else:
            parent = programarea_wa
    else:
        print('Unkwown verpflichtungsgrad "' + verpflichtungsgrad + '" of ' + name)
        return
    
    abbreviation = getAbbreviation(name, check_duplicate=False, word_length=2, max_words=3)
    
    identifier = parent.identifier + '_' + abbreviation

    desc = scrapeDescription(split, en)
    # duration = scrapeDuration(text, en)
    credits = scrapeCredits(first_20_lines, en)

    
    # print('\nname: ')
    # print(name)
    # print('\nidentifier: ')
    # print(identifier)
    # print('\nverpflichtungsgrad: ')
    # print(verpflichtungsgrad)
    # print('\ndesc: ')
    # print(desc)
    # print('\nduration: ')
    # print(duration)
    # print('\ncredits: ')
    # print(credits)
    
    modulhandbuch.addModul(name, identifier, parent.identifier, desc, url, '', credits)

# %%
modulhandbuch.modules = []

def scrapeModules():
    for program in modulhandbuch.programs:
        if program.parent != '13' and program.parent != '12':
            # print('Skipped: ' + program.identifier)
            continue
        modulhandbuch_urls = getModulhandbuchURLs(program.url)
        if modulhandbuch_urls:
            for url in modulhandbuch_urls:
                scrapeModulhandbuchPDF(url, program)
        else:
            print('Couldnt find any modulhandbücher online for ' + program.identifier)
        

def getModulhandbuchURLs(url):
    urls = getWeiteres(url)
    if urls:
        return urls
    
    urls = getStudienverlauf(url)
    if urls:
        return urls


def getStudienverlauf(url):
    weiteres_url = url + 'studienverlauf/'
    r = requests.get(weiteres_url)

    # Check status code for response received
    if r.status_code not in range(200, 300):
        print('Status ' + str(r.status_code) + ' at  ' + weiteres_url)
        return None

    # Parsing the HTML
    soup = bs(r.content, 'html.parser')

    modul_links = [ 
        link['href'] for link in soup.find_all('a', href=True) if re.match(r'^https:\/\/.*Plne%20und%20bersichten\/(.*)\.pdf$', link['href'])
    ]
    
    if len(modul_links) == 0:
        print('Kein Modulhanbuch gefunden auf ' + weiteres_url)
        return None
    else:
        # print('Modulhanbuch gefunden für ' + program.identifier)
        return modul_links   


def getWeiteres(url):
    weiteres_url = url + 'weiteres/'
    r = requests.get(weiteres_url)

    # Check status code for response received
    if r.status_code not in range(200, 300):
        print('Status ' + str(r.status_code) + ' at  ' + weiteres_url)
        return None

    # Parsing the HTML
    soup = bs(r.content, 'html.parser')

    modul_links = [ 
        link['href'] for link in soup.find_all('a', href=True) if re.match(r'^https:\/\/.*Plne%20und%20bersichten\/(.*_)?Modulhandbuch(_.*)?\.pdf$', link['href'])
    ]
    
    if len(modul_links) == 0:
        print('Kein Modulhanbuch gefunden auf ' + weiteres_url)
        return None
    else:
        # print('Modulhanbuch gefunden für ' + program.identifier)
        return [modul_links[0]]

pdf_blacklist = ['THL_Campusplan']

def scrapeModulhandbuchPDF(url, program):
    faculty = modulhandbuch.getFaculty(identifier=program.parent)
    if faculty == None:
        print('Couldnt find faculy for: ' + program.parent)
        return
    stupo = modulhandbuch.getStupo(parent = program.identifier)
    if stupo == None:
        print('Couldnt find stupo for: ' + program.identifier)
        return

    dirname = 'output/pdf/' + faculty.abbreviation + '/modulhandbuecher/' + program.identifier
    if not os.path.exists(dirname):
        os.makedirs(dirname)
    if 'Modulhandbuch' in url:
        filename = dirname + '/' + program.identifier + '_Modulhandbuch.pdf'
    else:
        match = re.search(r'^https:\/\/.*Plne%20und%20bersichten\/(.*)\.pdf$', url)
        if match:
            if match.group(1) in pdf_blacklist:
                print('Skipped blacklisted pdf with name: ' + match.group(1))
                return
            filename = dirname + '/' + match.group(1) + '.pdf'
    
    if not exists(filename):
        # Download modulhandbuch pdf.
        pdf_response = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(pdf_response.content)
    
    try:
        with pdfplumber.open(filename) as pdf:
            text = pdf.pages[0].extract_text()
            if text.startswith('Fachbereich'):
                scrapeModulhandbuchPDF_v1(pdf, url, stupo, en='hours per week' in text)
            elif text.startswith('Modulhandbuch') or 'Modul: ' in text or 'Module: ' in text:
                scrapeModulhandbuchPDF_v2(pdf, url, stupo, en='Module: ' in text)
            elif text.startswith('Formular für Modulbeschreibungen'):
                scrapeModulhandbuchPDF_v2(pdf, url, stupo, version=2)
            elif 'Pflicht/ Wahlpflicht' in text:
                scrapeModulhandbuchPDF_v3(pdf, url, stupo)
            else:
                print('Unkown pdf format for ' + stupo.name + ':')
                print(text[:400])
    # except (IOError, OSError) as e:
    except Exception as e:
        print('Error trying to read pdf: ', e)
        print('Couldnt open file with name: ' + filename)
        os.remove(filename)


scrapeModules()
# Out:
# Couldnt get name of module in Bauingenieurwesen Master SPO 2017
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/elektrotechnik-energiesysteme-und-automation-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/elektrotechnik-kommunikationssysteme-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/informatik-softwaretechnik-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/informationstechnologie-und-design-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/medieninformatik-online-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/regenerative-energien-online-beng/weiteres/
# Couldnt get Verpflichtungsgrad of Wahlpflichtfach III
# 24 Wahlpflichtfach III
# Semester 5
# Dauer (Semester) einsemestrig
# Credit Points 5
# Pflicht/ Wahlpflicht
# Modulverantwortliche(r) Jeweils betreuender Professor/ betreuende Professorin
# Teilnahmevoraussetzungen
# Lernergebnisse Lernergebnisse des aus dem Wahlpflichtbereich gewählten Moduls
# Skipped blacklisted pdf with name: THL_Campusplan
# Kein Modulhanbuch gefunden auf https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/angewandte-informationstechnik-msc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/informatik-softwaretechnik-fuer-verteilte-systeme-msc/weiteres/
# Error trying to read pdf:  No /Root object! - Is this really a PDF?
# Couldnt open file with name: output/pdf/EI/modulhandbuecher/EI_INF-VER-SYS-MA/INF_M1_Verteilte_Datenbank-_und_Informationssysteme.pdf
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/medieninformatik-online-msc/weiteres/
# Error trying to read pdf:  No /Root object! - Is this really a PDF?
# Couldnt open file with name: output/pdf/EI/modulhandbuecher/EI_MED-ONL-MA/MIM_1_Verfahren_und_Werkzeuge_moderner_Softwareentwicklung.pdf
# Error trying to read pdf:  No /Root object! - Is this really a PDF?
# Couldnt open file with name: output/pdf/EI/modulhandbuecher/EI_MED-ONL-MA/MIM_1_%20K%C3%BCnstliche_Intelligenz.pdf
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/it-sicherheit-online-bsc/weiteres/
# Skipped blacklisted pdf with name: THL_Campusplan
# Status 404 at  https://www.th-luebeck.de/hochschule/fachbereich-elektrotechnik-und-informatik/studiengaenge/allgemeine-elektrotechnik-bsc/weiteres/
# Unkown pdf format for Allgemeine Elektrotechnik Bachelor SPO 2019:
#
# 7.3 Modul Bachelorarbeit und Kolloquium
# Modulbezeichnung  Bachelorarbeit und Kolloquium
# Kürzel für Stundenplan  BmK
# Semester  7
# Modulverantwortliche(r)  Prof. Dr. Gunnar Schmidt
# Dozent(in)  -
# Sprache  Deutsch und Englisch
# Zuordnung zum Curriculum  KIM – Pflichtmodul
# Lehrform / SWS  selbstständige Abschlussarbeit
# Arbeitsaufwand  360 h Erstellen der Bachelorarbeit
# 90 h Vorbereitung und D
# Unkown pdf format for Allgemeine Elektrotechnik Bachelor SPO 2019:
#
# 7.3 Modul Bachelorarbeit und Kolloquium
# Modulbezeichnung  Bachelorarbeit und Kolloquium
# Kürzel für Stundenplan  BmK
# Semester  7
# Modulverantwortliche(r)  Prof. Dr. Gunnar Schmidt
# Dozent(in)  -
# Sprache  Deutsch und Englisch
# Zuordnung zum Curriculum  KIM – Pflichtmodul
# Lehrform / SWS  selbstständige Abschlussarbeit
# Arbeitsaufwand  360 h Erstellen der Bachelorarbeit
# 90 h Vorbereitung und D
# Skipped blacklisted pdf with name: THL_Campusplan

# %%
program_name_matching = {
    'Energie- und Gebäudeingenieurwesen': 'Nachhaltige Gebäudetechnik',
    'Informatik/Softwaretechnik': 'Informatik/ Softwaretechnik',
    'Bachelor Stadtplanung': 'Stadtplanung',
    'Electrical Engineering - Communication Systems': 'Elektrotechnik - Kommunikationssysteme',
    'Applied Information Technology': 'Angewandte Informationstechnik',
    'Electrical Engineering - Energy Systems and Automation Engineering': 'Elektrotechnik - Energiesysteme und Automation',
    'Computer Science/Software Engineering for Distributed Systems': 'Informatik/Softwaretechnik für verteilte Systeme',
}

def parseXML(xml):
    facultyname = xml['Modulbeschreibungen']['Modulbeschreibung'][0]['Modul']['M_Fachbereich']
    if facultyname != 'Bauwesen' and facultyname != 'Elektrotechnik und Informatik':
        return
    
    modul_xml = xml['Modulbeschreibungen']['Modulbeschreibung'][0]['Modul']
    
    m_studiengang = modul_xml['M_Studiengang']
    if not m_studiengang:
        print('Couldnt find m_studiengang')
        return
    base_program_name = re.sub(r'(, Bachelor)|(, Master)', '', m_studiengang)

    if base_program_name in program_name_matching.keys():
        base_program_name = program_name_matching[base_program_name]

    base_qualification = modul_xml['M_Niveau']
    if not base_qualification:
        print('No qualification found for ' + base_program_name)
        return
    base_qualification = parseQualification(base_qualification)

    base_program = modulhandbuch.getProgram(base_program_name, base_qualification)
    
    
    for modulbeschreibungen_xml in xml['Modulbeschreibungen']['Modulbeschreibung']:
        modul_xml = modulbeschreibungen_xml['Modul']
        lehrveranstaltungen_xml = modulbeschreibungen_xml['Lehrveranstaltungen']

        modul_name = modul_xml['M_Modulname']
        if not modul_name:
            print('No modul name found')
            continue
        qualification = modul_xml['M_Niveau']
        if not qualification:
            qualification = base_qualification
        else:
            qualification = parseQualification(qualification)

        m_studiengang = modul_xml['M_Studiengang']
        if not m_studiengang:
            program = base_program
        else:
            program_name = re.sub(r'(, Bachelor)|(, Master)', '', m_studiengang)
            if program_name in program_name_matching.keys():
                program_name = program_name_matching[program_name]

            program = modulhandbuch.getProgram(program_name, qualification)
            if not program:
                print('Couldnt find program for name: ' + program_name)
                return

        modul_index = modulhandbuch.getModulIndex(name=modul_name, childof=program.identifier)
        modul = ''
        if not modul_index:
            print('Modul not yet in modulhandbuch: ' + modul_name)
            modul = addModulFromXML(modul_xml, modul_name, program)
        else:
            print('Update existing modul: ' + modul_name)
            modul = updateModulWithXML(modul_xml, modul_index)
        
        if modul:
            childModules = [addLehrveranstaltungFromXML(lehrveranstaltungen_xml[key], modul, str(index+1)) for (
                index, key) in enumerate(lehrveranstaltungen_xml)]
            
            print('Added ' + str(len(childModules)) + ' child modules for: ' + modul_name)

def addModulFromXML(modul_xml, name, program):
        
    stupo = modulhandbuch.getStupo(parent=program.identifier)
    if not stupo:
        print('Couldnt find parent of modul_xml: ', name)
        return
    
    programarea_pf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_PF')
    if not programarea_pf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_PF')
        return
    programarea_wapf = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WAPF')
    if not programarea_wapf:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WAPF')
        return
    programarea_wa = modulhandbuch.getProgramarea(identifier=stupo.identifier + '_WA')
    if not programarea_wa:
        print('Couldnt get programe area with identifier: ' + stupo.identifier + '_WA')
        return
    
    if modul_xml['M_Verpflichtungsgrad']:
        verpflichtungsgrad = modul_xml['M_Verpflichtungsgrad']
        if verpflichtungsgrad == 'Pflicht' or verpflichtungsgrad == 'Compulsory':
            parent = programarea_pf
        elif verpflichtungsgrad == 'Wahlpflicht' or verpflichtungsgrad == 'Compulsory elective':
            parent = programarea_wapf
        elif verpflichtungsgrad == 'Wahl' or verpflichtungsgrad == 'Elective':
            parent = programarea_wa
        else:
            print('Unkwown verpflichtungsgrad "' + verpflichtungsgrad + '" of ' + name)
            return
    else:
        parent = programarea_wa

    if modul_xml['M_Stundenplankuerzel']:
        identifier = parent.identifier + '_' + modul_xml['M_Stundenplankuerzel']
    else:
        identifier = parent.identifier + '_' + getAbbreviation(name, check_duplicate=False, word_length=2, max_words=3)

    if modul_xml['M_Lernergebnisse']:
        desc = unpackDict(modul_xml['M_Lernergebnisse']['html']['body'])
    else:
        # print('Couldnt find desc for modul_xml: ', name)
        desc = ''

    duration = int(modul_xml['M_Dauer_in_Semestern']) * 6
    if duration:
        duration = str(duration) + ' Monate'
    else:
        print('Couldnt find duration for modul_xml: ', name)
        duration = ''
    
    credits = modul_xml['M_ECTS_Leistungspunkte']
    return modulhandbuch.addModul(name, identifier, parent.identifier, desc, '', duration, credits)
    
def addLehrveranstaltungFromXML(lv_xml, parent, index):
    if lv_xml['L'+index+'_Lehrveranstaltungsart']:
        name = lv_xml['L'+index+'_Lehrveranstaltungsname']
    else:
        return
    
    identifier = ''
    if lv_xml['L'+index+'_Lehrveranstaltungsart']:
        lehrveranstaltungsart = lv_xml['L'+index+'_Lehrveranstaltungsart']
        if not lehrveranstaltungsart:
            identifier = parent.identifier + '_' + index
        elif lehrveranstaltungsart == 'Vorlesung' or lehrveranstaltungsart == 'Lecture':
            identifier = parent.identifier + '_V'
        elif lehrveranstaltungsart == 'Projekt' or lehrveranstaltungsart == 'Project Work':
            identifier = parent.identifier + '_Pj'
        elif lehrveranstaltungsart == 'Praktikum' or lehrveranstaltungsart == 'Practical Training':
            identifier = parent.identifier + '_Pr'
        elif lehrveranstaltungsart == 'Übung' or lehrveranstaltungsart == 'Exercise':
            identifier = parent.identifier + '_Ü'
        elif lehrveranstaltungsart == 'Seminar' or lehrveranstaltungsart == 'Seminar':
            identifier = parent.identifier + '_S'
        elif lehrveranstaltungsart == 'Exkursion' or lehrveranstaltungsart == 'Excursion':
            identifier = parent.identifier + '_Ex'
        elif lehrveranstaltungsart == 'Online-':
            identifier = parent.identifier + '_O'
            lehrveranstaltungsart = 'Online'
        else: 
            print('Unkwon Lehrveranstaltungsart of ' + name, lehrveranstaltungsart)
            return
    if not identifier:
        identifier = parent.identifier + '_' + index

    if lv_xml['L'+index+'_Lehrinhalte']:
        desc = unpackDict(lv_xml['L'+index+'_Lehrinhalte']['html']['body'])
    else:
        desc = ''
    
    
    return modulhandbuch.addModul(name, identifier, parent.identifier, desc, '', '', '')

def updateModulWithXML(modul_xml, index):
    modul = modulhandbuch.modules[index]

    if modul_xml['M_Stundenplankuerzel']:
        identifier = modul.parent + '_' + modul_xml['M_Stundenplankuerzel']
    else:
        identifier = modul.identifier
    
    if modul_xml['M_Lernergebnisse']:
        desc = unpackDict(modul_xml['M_Lernergebnisse']['html']['body'])
    else:
        desc = modul.desc
    
    duration = int(modul_xml['M_Dauer_in_Semestern']) * 6
    if duration:
        duration = str(duration) + ' Monate'
    else:
        duration = ''
    
    credits = modul_xml['M_ECTS_Leistungspunkte']
    
    children = modulhandbuch.getModulChildren(modul.identifier)
    for child in children:
        # child_index = modulhandbuch.getModulIndex(identifier=child.identifier, childof=modul.parent)
        # if child_index:
        modulhandbuch.modules.remove(child)
            
    print('Dleteted ' + str(len(children)) + ' child modules for: ' + modul.name)
    
    return modulhandbuch.updateModul(index, modul.name, identifier, modul.parent, desc, '', duration, credits)


def cleanHtml(text):
    if not text:
        return ''

    if not isinstance(text, str):
        print(text)

    text = re.sub(r'<li>', '- ', text)
    # text = re.sub(r'</li>', '\n- ', text)
    text = re.sub(r' +', ' ', text)
    text = re.sub(r'</?\w+>', '', text)
    # text = re.sub(r'</\w+>', '', text)
    return text.strip()

# Returns only the text inside a given dictionary, and formats the the text according to the xml tag
def unpackDict(d, key=''):
    result = ''
    if isinstance(d, dict):
        for (k, v) in d.items():
            if key == 'li':
                result += '\t- '
            result += unpackDict(v, k)
            if((k == 'li' or k == 'p') and not result.endswith('\n')):
                result += "\n"
    elif isinstance(d, list):
        for v in d:
            if key == 'li':
                result += '\t- '
            result += unpackDict(v)
            if not result.endswith('\n'):
                result += '\n'
    elif isinstance(d, str):
        result += d
        result = result.strip()

    return result

def scanModulhandbuchXML():
    # Open a file
    path = r'./input'

    # Generate new XML for every file in the subdirectories of the input folder
    with os.scandir(path) as dirs:
        for dir in dirs:
            if os.path.isdir(dir):
                with os.scandir(dir) as subdir:
                    for file in subdir:
                        if os.path.isfile(file):
                            # Read THL Moduldescriptions and convert them to dictionaries
                            xml_in = open(
                                file, 'r', encoding='utf-8').read()
                            # print(file)
                            xml_in = xmltodict.parse(xml_in)

                            parseXML(xml_in)


scanModulhandbuchXML()
# Out:
# Update existing modul: Entwerfen und Konstruieren I (inkl. Kompaktwochen)
# Dleteted 1 child modules for: Entwerfen und Konstruieren I (inkl. Kompaktwochen)
# Added 2 child modules for: Entwerfen und Konstruieren I (inkl. Kompaktwochen)
# Update existing modul: Grundlagen Digitale Methoden
# Dleteted 1 child modules for: Grundlagen Digitale Methoden
# Added 2 child modules for: Grundlagen Digitale Methoden
# Update existing modul: Bau- und Stadtbaugeschichte
# Dleteted 2 child modules for: Bau- und Stadtbaugeschichte
# Added 2 child modules for: Bau- und Stadtbaugeschichte
# Update existing modul: Gestalten und Darstellen I
# Dleteted 2 child modules for: Gestalten und Darstellen I
# Added 2 child modules for: Gestalten und Darstellen I
# Update existing modul: Baustoffe I
# Dleteted 1 child modules for: Baustoffe I
# Added 2 child modules for: Baustoffe I
# Update existing modul: Tragwerkslehre I und Bauphysik I
# Dleteted 1 child modules for: Tragwerkslehre I und Bauphysik I
# Added 2 child modules for: Tragwerkslehre I und Bauphysik I
# Update existing modul: Entwerfen und Konstruieren II (inkl. Gebäudekunde und Baugestaltung)
# Dleteted 1 child modules for: Entwerfen und Konstruieren II (inkl. Gebäudekunde und Baugestaltung)
# Added 2 child modules for: Entwerfen und Konstruieren II (inkl. Gebäudekunde und Baugestaltung)
# Update existing modul: Entwurfsmethodik
# Dleteted 1 child modules for: Entwurfsmethodik
# Added 2 child modules for: Entwurfsmethodik
# Update existing modul: Bau- und Stadtbaugeschichte
# Dleteted 1 child modules for: Bau- und Stadtbaugeschichte
# Added 2 child modules for: Bau- und Stadtbaugeschichte
# Update existing modul: Gestalten und Darstellen II
# Dleteted 1 child modules for: Gestalten und Darstellen II
# Added 2 child modules for: Gestalten und Darstellen II
# Update existing modul: Baustoffe II
# Dleteted 1 child modules for: Baustoffe II
# Added 2 child modules for: Baustoffe II
# Update existing modul: Tragwerkslehre II
# Dleteted 1 child modules for: Tragwerkslehre II
# Added 2 child modules for: Tragwerkslehre II
# Update existing modul: Bauphysik II
# Dleteted 1 child modules for: Bauphysik II
# Added 4 child modules for: Bauphysik II
# Update existing modul: Entwerfen und Konstruieren III (inkl. Pflichtexkursion)
# Dleteted 1 child modules for: Entwerfen und Konstruieren III (inkl. Pflichtexkursion)
# Added 2 child modules for: Entwerfen und Konstruieren III (inkl. Pflichtexkursion)
# Update existing modul: Grundlagen des Städtebaus und der Freiraumplanung
# Dleteted 1 child modules for: Grundlagen des Städtebaus und der Freiraumplanung
# Added 2 child modules for: Grundlagen des Städtebaus und der Freiraumplanung
# Update existing modul: Baumanagement I
# Dleteted 1 child modules for: Baumanagement I
# Added 2 child modules for: Baumanagement I
# Update existing modul: Technischer Ausbau
# Dleteted 1 child modules for: Technischer Ausbau
# Added 2 child modules for: Technischer Ausbau
# Update existing modul: Bauphysik III
# Dleteted 1 child modules for: Bauphysik III
# Added 4 child modules for: Bauphysik III
# Update existing modul: Entwerfen und Konstruieren IV
# Dleteted 1 child modules for: Entwerfen und Konstruieren IV
# Added 2 child modules for: Entwerfen und Konstruieren IV
# Update existing modul: Baurecht
# Dleteted 1 child modules for: Baurecht
# Added 2 child modules for: Baurecht
# Update existing modul: Architekturtheorie
# Dleteted 1 child modules for: Architekturtheorie
# Added 2 child modules for: Architekturtheorie
# Update existing modul: Gestalten und Darstellen III
# Dleteted 1 child modules for: Gestalten und Darstellen III
# Added 2 child modules for: Gestalten und Darstellen III
# Update existing modul: Grundlagen Digitales Entwerfen
# Dleteted 1 child modules for: Grundlagen Digitales Entwerfen
# Added 2 child modules for: Grundlagen Digitales Entwerfen
# Update existing modul: Nachhaltiges Bauen
# Dleteted 1 child modules for: Nachhaltiges Bauen
# Added 2 child modules for: Nachhaltiges Bauen
# Update existing modul: Entwerfen und Konstruieren V
# Dleteted 1 child modules for: Entwerfen und Konstruieren V
# Added 2 child modules for: Entwerfen und Konstruieren V
# Update existing modul: Sonderthema Architektur I
# Dleteted 1 child modules for: Sonderthema Architektur I
# Added 2 child modules for: Sonderthema Architektur I
# Update existing modul: Städtebauliches Projekt I
# Dleteted 1 child modules for: Städtebauliches Projekt I
# Added 2 child modules for: Städtebauliches Projekt I
# Update existing modul: Seminar Geschichte und Theorie der Architektur (inkl. Wiss. Studienarbeit)
# Dleteted 1 child modules for: Seminar Geschichte und Theorie der Architektur (inkl. Wiss. Studienarbeit)
# Added 2 child modules for: Seminar Geschichte und Theorie der Architektur (inkl. Wiss. Studienarbeit)
# Update existing modul: Grundlagen Digitales Konstruieren
# Dleteted 1 child modules for: Grundlagen Digitales Konstruieren
# Added 2 child modules for: Grundlagen Digitales Konstruieren
# Update existing modul: Baumanagement II
# Dleteted 1 child modules for: Baumanagement II
# Added 2 child modules for: Baumanagement II
# Update existing modul: Entwerfen und Konstruieren VI
# Dleteted 1 child modules for: Entwerfen und Konstruieren VI
# Added 2 child modules for: Entwerfen und Konstruieren VI
# Update existing modul: Sonderthema Architektur II
# Dleteted 1 child modules for: Sonderthema Architektur II
# Added 2 child modules for: Sonderthema Architektur II
# Update existing modul: Städtebauliches Projekt II
# Dleteted 1 child modules for: Städtebauliches Projekt II
# Added 2 child modules for: Städtebauliches Projekt II
# Update existing modul: Projekt Digitales Entwerfen und Konstruieren
# Dleteted 1 child modules for: Projekt Digitales Entwerfen und Konstruieren
# Added 2 child modules for: Projekt Digitales Entwerfen und Konstruieren
# Update existing modul: Sonderthema Architektur III
# Dleteted 1 child modules for: Sonderthema Architektur III
# Added 2 child modules for: Sonderthema Architektur III
# Update existing modul: Stegreife
# Dleteted 1 child modules for: Stegreife
# Added 2 child modules for: Stegreife
# Update existing modul: Bachelorseminar
# Dleteted 1 child modules for: Bachelorseminar
# Added 2 child modules for: Bachelorseminar
# Update existing modul: Sonderthema Architektur IV
# Dleteted 1 child modules for: Sonderthema Architektur IV
# Added 2 child modules for: Sonderthema Architektur IV
# Update existing modul: Visualisierung Bachelorarbeit
# Dleteted 1 child modules for: Visualisierung Bachelorarbeit
# Added 2 child modules for: Visualisierung Bachelorarbeit
# Update existing modul: Bachelorarbeit (10 Kalenderwochen) und Abschlusskolloquium
# Dleteted 1 child modules for: Bachelorarbeit (10 Kalenderwochen) und Abschlusskolloquium
# Added 2 child modules for: Bachelorarbeit (10 Kalenderwochen) und Abschlusskolloquium
# Update existing modul: Bauen im Bestand I
# Dleteted 1 child modules for: Bauen im Bestand I
# Added 2 child modules for: Bauen im Bestand I
# Update existing modul: Digitales Bauen I
# Dleteted 1 child modules for: Digitales Bauen I
# Added 2 child modules for: Digitales Bauen I
# Update existing modul: Nachhaltiges Bauen I
# Dleteted 2 child modules for: Nachhaltiges Bauen I
# Added 2 child modules for: Nachhaltiges Bauen I
# Update existing modul: Forschung im Bestand I
# Dleteted 1 child modules for: Forschung im Bestand I
# Added 2 child modules for: Forschung im Bestand I
# Update existing modul: Digitale Prozesse I
# Dleteted 1 child modules for: Digitale Prozesse I
# Added 2 child modules for: Digitale Prozesse I
# Update existing modul: Nachhaltiges Bauen I
# Dleteted 1 child modules for: Nachhaltiges Bauen I
# Added 2 child modules for: Nachhaltiges Bauen I
# Update existing modul: Nachhaltige Baukonstruktion I
# Dleteted 2 child modules for: Nachhaltige Baukonstruktion I
# Added 2 child modules for: Nachhaltige Baukonstruktion I
# Update existing modul: Wohnungswesen und Wohnungsbau
# Dleteted 1 child modules for: Wohnungswesen und Wohnungsbau
# Added 2 child modules for: Wohnungswesen und Wohnungsbau
# Update existing modul: Partizipation und Kommunikation
# Dleteted 1 child modules for: Partizipation und Kommunikation
# Added 2 child modules for: Partizipation und Kommunikation
# Update existing modul: Sonderthemen in Architektur und Planung I
# Dleteted 1 child modules for: Sonderthemen in Architektur und Planung I
# Added 2 child modules for: Sonderthemen in Architektur und Planung I
# Update existing modul: Sonderthemen in Architektur und Planung II
# Dleteted 1 child modules for: Sonderthemen in Architektur und Planung II
# Added 2 child modules for: Sonderthemen in Architektur und Planung II
# Update existing modul: Bauen im Bestand II
# Dleteted 1 child modules for: Bauen im Bestand II
# Added 2 child modules for: Bauen im Bestand II
# Update existing modul: Digitales Bauen II
# Dleteted 1 child modules for: Digitales Bauen II
# Added 2 child modules for: Digitales Bauen II
# Update existing modul: Nachhaltiges Bauen II
# Dleteted 1 child modules for: Nachhaltiges Bauen II
# Added 2 child modules for: Nachhaltiges Bauen II
# Update existing modul: Interdisziplinäre Sonderwoche
# Dleteted 1 child modules for: Interdisziplinäre Sonderwoche
# Added 2 child modules for: Interdisziplinäre Sonderwoche
# Update existing modul: Forschung im Bestand II
# Dleteted 1 child modules for: Forschung im Bestand II
# Added 2 child modules for: Forschung im Bestand II
# Update existing modul: Digitale Prozesse II
# Dleteted 1 child modules for: Digitale Prozesse II
# Added 2 child modules for: Digitale Prozesse II
# Update existing modul: Nachhaltige Baukonstruktion II
# Dleteted 1 child modules for: Nachhaltige Baukonstruktion II
# Added 2 child modules for: Nachhaltige Baukonstruktion II
# Update existing modul: Städtebauliche Gestaltung und Freiraumplanung
# Dleteted 1 child modules for: Städtebauliche Gestaltung und Freiraumplanung
# Added 2 child modules for: Städtebauliche Gestaltung und Freiraumplanung
# Update existing modul: Masterseminar
# Dleteted 1 child modules for: Masterseminar
# Added 2 child modules for: Masterseminar
# Update existing modul: Masterarbeit (16 Kalenderwochen) und Abschlusskolloquium
# Dleteted 1 child modules for: Masterarbeit (16 Kalenderwochen) und Abschlusskolloquium
# Added 2 child modules for: Masterarbeit (16 Kalenderwochen) und Abschlusskolloquium
# Update existing modul: Kompaktwochen
# Dleteted 1 child modules for: Kompaktwochen
# Added 2 child modules for: Kompaktwochen
# Update existing modul: Klimaschutz und Nachhaltigkeit
# Dleteted 1 child modules for: Klimaschutz und Nachhaltigkeit
# Added 2 child modules for: Klimaschutz und Nachhaltigkeit
# Update existing modul: Ingenieurmathematik I
# Dleteted 1 child modules for: Ingenieurmathematik I
# Added 2 child modules for: Ingenieurmathematik I
# Update existing modul: Physik
# Dleteted 1 child modules for: Physik
# Added 2 child modules for: Physik
# Update existing modul: Chemie
# Dleteted 1 child modules for: Chemie
# Added 2 child modules for: Chemie
#  Baustoffe BAU_NGB
# Modul not yet in modulhandbuch: Baustoffe
# Added 2 child modules for: Baustoffe
# Update existing modul: Baukonstruktion I
# Dleteted 1 child modules for: Baukonstruktion I
# Added 2 child modules for: Baukonstruktion I
# Update existing modul: Bauphysik
# Dleteted 1 child modules for: Bauphysik
# Added 2 child modules for: Bauphysik
# Update existing modul: Grundlagen CAD
# Dleteted 1 child modules for: Grundlagen CAD
# Added 2 child modules for: Grundlagen CAD
# Update existing modul: Ingenieurmathematik II
# Dleteted 2 child modules for: Ingenieurmathematik II
# Added 2 child modules for: Ingenieurmathematik II
# Update existing modul: Angewandte Informatik
# Dleteted 1 child modules for: Angewandte Informatik
# Added 2 child modules for: Angewandte Informatik
# Update existing modul: Gebäudelehre
# Dleteted 1 child modules for: Gebäudelehre
# Added 2 child modules for: Gebäudelehre
# Update existing modul: Baukonstruktion II
# Dleteted 1 child modules for: Baukonstruktion II
# Added 2 child modules for: Baukonstruktion II
# Update existing modul: Tragwerkslehre
# Dleteted 1 child modules for: Tragwerkslehre
# Added 2 child modules for: Tragwerkslehre
# Update existing modul: Grundlagen der Elektrotechnik
# Dleteted 1 child modules for: Grundlagen der Elektrotechnik
# Added 2 child modules for: Grundlagen der Elektrotechnik
# Update existing modul: Grundlagen der MSR-Technik
# Dleteted 1 child modules for: Grundlagen der MSR-Technik
# Added 2 child modules for: Grundlagen der MSR-Technik
# Update existing modul: Thermodynamik
# Dleteted 1 child modules for: Thermodynamik
# Added 2 child modules for: Thermodynamik
# Update existing modul: Strömungslehre
# Dleteted 1 child modules for: Strömungslehre
# Added 2 child modules for: Strömungslehre
# Update existing modul: Baugestaltung
# Dleteted 1 child modules for: Baugestaltung
# Added 2 child modules for: Baugestaltung
#  Baubetrieb BAU_NGB
# Modul not yet in modulhandbuch: Baubetrieb
# Added 2 child modules for: Baubetrieb
# Update existing modul: Grundlagen der Energietechnik
# Dleteted 1 child modules for: Grundlagen der Energietechnik
# Added 2 child modules for: Grundlagen der Energietechnik
#  Nachhaltigkeit und Lebenszyklus BAU_NGB
# Modul not yet in modulhandbuch: Nachhaltigkeit und Lebenszyklus
# Added 2 child modules for: Nachhaltigkeit und Lebenszyklus
#  Technischer Ausbau I: Wärme-/Kälteversorgungsanlagen BAU_NGB
# Modul not yet in modulhandbuch: Technischer Ausbau I: Wärme-/Kälteversorgungsanlagen
# Added 2 child modules for: Technischer Ausbau I: Wärme-/Kälteversorgungsanlagen
# Update existing modul: Technischer Ausbau II: Sanitäre Systeme
# Dleteted 1 child modules for: Technischer Ausbau II: Sanitäre Systeme
# Added 2 child modules for: Technischer Ausbau II: Sanitäre Systeme
# Update existing modul: Technischer Ausbau III: Elektrische Systeme
# Dleteted 1 child modules for: Technischer Ausbau III: Elektrische Systeme
# Added 2 child modules for: Technischer Ausbau III: Elektrische Systeme
# Update existing modul: Baurecht
# Dleteted 1 child modules for: Baurecht
# Added 2 child modules for: Baurecht
# Update existing modul: Projekt GEG und Lebenszyklus
# Dleteted 1 child modules for: Projekt GEG und Lebenszyklus
# Added 2 child modules for: Projekt GEG und Lebenszyklus
# Update existing modul: Regenerative Energien
# Dleteted 1 child modules for: Regenerative Energien
# Added 2 child modules for: Regenerative Energien
# Update existing modul: Technischer Ausbau IV: Raumlufttechnische Anlagen
# Dleteted 1 child modules for: Technischer Ausbau IV: Raumlufttechnische Anlagen
# Added 2 child modules for: Technischer Ausbau IV: Raumlufttechnische Anlagen
# Update existing modul: Technischer Ausbau V: Gebäudeautomation
# Dleteted 1 child modules for: Technischer Ausbau V: Gebäudeautomation
# Added 2 child modules for: Technischer Ausbau V: Gebäudeautomation
# Update existing modul: BIM Integrale Planung
# Dleteted 1 child modules for: BIM Integrale Planung
# Added 2 child modules for: BIM Integrale Planung
# Update existing modul: Interdisziplinäres Projekt
# Dleteted 1 child modules for: Interdisziplinäres Projekt
# Added 2 child modules for: Interdisziplinäres Projekt
# Update existing modul: Technischer Ausbau VI: Lichtplanung
# Dleteted 1 child modules for: Technischer Ausbau VI: Lichtplanung
# Added 2 child modules for: Technischer Ausbau VI: Lichtplanung
# Update existing modul: Gebäude- und Anlagensimulation
# Dleteted 1 child modules for: Gebäude- und Anlagensimulation
# Added 2 child modules for: Gebäude- und Anlagensimulation
# Update existing modul: Wissenschaftliche Studienarbeit
# Dleteted 1 child modules for: Wissenschaftliche Studienarbeit
# Added 2 child modules for: Wissenschaftliche Studienarbeit
# Update existing modul: Brandschutz
# Dleteted 1 child modules for: Brandschutz
# Added 2 child modules for: Brandschutz
# Update existing modul: Berufspraktikum, Praktikumsseminar
# Dleteted 1 child modules for: Berufspraktikum, Praktikumsseminar
# Added 2 child modules for: Berufspraktikum, Praktikumsseminar
# Update existing modul: Bachelorseminar
# Dleteted 1 child modules for: Bachelorseminar
# Added 2 child modules for: Bachelorseminar
# Update existing modul: Bachelorarbeit
# Dleteted 21 child modules for: Bachelorarbeit
# Added 2 child modules for: Bachelorarbeit
# Update existing modul: Bachelorkolloqium
# Dleteted 1 child modules for: Bachelorkolloqium
# Added 2 child modules for: Bachelorkolloqium
# Update existing modul: Einstiegsmodul
# Dleteted 1 child modules for: Einstiegsmodul
# Added 2 child modules for: Einstiegsmodul
# Update existing modul: Darstellungsmethoden / CAD
# Dleteted 1 child modules for: Darstellungsmethoden / CAD
# Added 2 child modules for: Darstellungsmethoden / CAD
# Update existing modul: Grundlagen der Stadtplanung und der Stadtentwicklung
# Dleteted 1 child modules for: Grundlagen der Stadtplanung und der Stadtentwicklung
# Added 2 child modules for: Grundlagen der Stadtplanung und der Stadtentwicklung
# Update existing modul: Bau- und Stadtbaugeschichte
# Dleteted 1 child modules for: Bau- und Stadtbaugeschichte
# Added 2 child modules for: Bau- und Stadtbaugeschichte
# Update existing modul: Bau- und Planungsrecht I
# Dleteted 1 child modules for: Bau- und Planungsrecht I
# Added 2 child modules for: Bau- und Planungsrecht I
# Update existing modul: Klimaschutz und Nachhaltigkeit
# Dleteted 1 child modules for: Klimaschutz und Nachhaltigkeit
# Added 2 child modules for: Klimaschutz und Nachhaltigkeit
# Update existing modul: Einstiegs- und Analyseprojekt
# Dleteted 1 child modules for: Einstiegs- und Analyseprojekt
# Added 2 child modules for: Einstiegs- und Analyseprojekt
# Update existing modul: Geoinformationssysteme / CAD
# Dleteted 1 child modules for: Geoinformationssysteme / CAD
# Added 2 child modules for: Geoinformationssysteme / CAD
# Update existing modul: Grundlagen des Städtebaus und der Freiraumplanung
# Dleteted 1 child modules for: Grundlagen des Städtebaus und der Freiraumplanung
# Added 2 child modules for: Grundlagen des Städtebaus und der Freiraumplanung
# Update existing modul: Gebäudelehre
# Dleteted 1 child modules for: Gebäudelehre
# Added 2 child modules for: Gebäudelehre
# Update existing modul: Technische Infrastruktur
# Dleteted 1 child modules for: Technische Infrastruktur
# Added 2 child modules for: Technische Infrastruktur
# Update existing modul: Städtebauliches Entwurfsprojekt
# Dleteted 1 child modules for: Städtebauliches Entwurfsprojekt
# Added 2 child modules for: Städtebauliches Entwurfsprojekt
# Update existing modul: Raumbezogenes Datenmanagement
# Dleteted 1 child modules for: Raumbezogenes Datenmanagement
# Added 2 child modules for: Raumbezogenes Datenmanagement
# Update existing modul: Wohn- und Stadtsoziologie
# Dleteted 1 child modules for: Wohn- und Stadtsoziologie
# Added 2 child modules for: Wohn- und Stadtsoziologie
# Update existing modul: Stadterneuerung und Regionale Entwicklung
# Dleteted 1 child modules for: Stadterneuerung und Regionale Entwicklung
# Added 2 child modules for: Stadterneuerung und Regionale Entwicklung
# Update existing modul: Bauleitplanung und Immobilienwirtschaft
# Dleteted 1 child modules for: Bauleitplanung und Immobilienwirtschaft
# Added 2 child modules for: Bauleitplanung und Immobilienwirtschaft
# Update existing modul: Verkehrsplanung u. -technik
# Dleteted 0 child modules for: Verkehrsplanung u. -technik
# Added 2 child modules for: Verkehrsplanung u. -technik
# Update existing modul: Stadt-Land-Projekt
# Dleteted 1 child modules for: Stadt-Land-Projekt
# Added 2 child modules for: Stadt-Land-Projekt
# Update existing modul: Daseinsvorsorge/soziale Infrastruktur//Meth. emp. Sozialforschung
# Dleteted 1 child modules for: Daseinsvorsorge/soziale Infrastruktur//Meth. emp. Sozialforschung
# Added 2 child modules for: Daseinsvorsorge/soziale Infrastruktur//Meth. emp. Sozialforschung
# Update existing modul: Planungstheorie und -methoden
# Dleteted 1 child modules for: Planungstheorie und -methoden
# Added 2 child modules for: Planungstheorie und -methoden
# Update existing modul: Kommunales Projektmanagement / Verwaltungsorganisation
# Dleteted 1 child modules for: Kommunales Projektmanagement / Verwaltungsorganisation
# Added 2 child modules for: Kommunales Projektmanagement / Verwaltungsorganisation
# Update existing modul: Bau- und Planungsrecht II
# Dleteted 1 child modules for: Bau- und Planungsrecht II
# Added 2 child modules for: Bau- und Planungsrecht II
# Update existing modul: Stadtökologie / Umweltplanung
# Dleteted 1 child modules for: Stadtökologie / Umweltplanung
# Added 2 child modules for: Stadtökologie / Umweltplanung
# Update existing modul: Planspiel-Projekt
# Dleteted 1 child modules for: Planspiel-Projekt
# Added 2 child modules for: Planspiel-Projekt
# Update existing modul: Praktikumsprojekt
# Dleteted 1 child modules for: Praktikumsprojekt
# Added 2 child modules for: Praktikumsprojekt
# Update existing modul: Wissenstransfer Praxis - Hochschule
# Dleteted 1 child modules for: Wissenstransfer Praxis - Hochschule
# Added 2 child modules for: Wissenstransfer Praxis - Hochschule
# Update existing modul: Exkursion
# Dleteted 1 child modules for: Exkursion
# Added 2 child modules for: Exkursion
# Update existing modul: Arbeit und Ressourcen
# Dleteted 1 child modules for: Arbeit und Ressourcen
# Added 2 child modules for: Arbeit und Ressourcen
# Update existing modul: Stadtbaukultur und Bestandsentwicklung
# Dleteted 1 child modules for: Stadtbaukultur und Bestandsentwicklung
# Added 2 child modules for: Stadtbaukultur und Bestandsentwicklung
# Update existing modul: Nachhaltigkeit und Mobilität
# Dleteted 1 child modules for: Nachhaltigkeit und Mobilität
# Added 2 child modules for: Nachhaltigkeit und Mobilität
# Update existing modul: Bachelorarbeit
# Dleteted 1 child modules for: Bachelorarbeit
# Added 2 child modules for: Bachelorarbeit
# Update existing modul: Bachelorkolloquium
# Dleteted 1 child modules for: Bachelorkolloquium
# Added 2 child modules for: Bachelorkolloquium
# Update existing modul: Studienprojekt: Städtebaulicher Entwurf
# Dleteted 1 child modules for: Studienprojekt: Städtebaulicher Entwurf
# Added 2 child modules for: Studienprojekt: Städtebaulicher Entwurf
# Update existing modul: Strategische und integrierte Planung
# Dleteted 1 child modules for: Strategische und integrierte Planung
# Added 2 child modules for: Strategische und integrierte Planung
# Update existing modul: Wohnungswesen und Quartiersentwicklung
# Dleteted 1 child modules for: Wohnungswesen und Quartiersentwicklung
# Added 2 child modules for: Wohnungswesen und Quartiersentwicklung
# Update existing modul: Stadt und Energie
# Dleteted 1 child modules for: Stadt und Energie
# Added 2 child modules for: Stadt und Energie
# Update existing modul: Studienprojekt Stadt und Quartier
# Dleteted 1 child modules for: Studienprojekt Stadt und Quartier
# Added 2 child modules for: Studienprojekt Stadt und Quartier
# Update existing modul: Klimawandel und Freiraumgestaltung
# Dleteted 1 child modules for: Klimawandel und Freiraumgestaltung
# Added 2 child modules for: Klimawandel und Freiraumgestaltung
# Update existing modul: Kommunikation und partizipative Prozesse in der Stadtentwicklung
# Dleteted 1 child modules for: Kommunikation und partizipative Prozesse in der Stadtentwicklung
# Added 2 child modules for: Kommunikation und partizipative Prozesse in der Stadtentwicklung
# Update existing modul: Studienprojekt Forschung und Synthese
# Dleteted 1 child modules for: Studienprojekt Forschung und Synthese
# Added 2 child modules for: Studienprojekt Forschung und Synthese
# Update existing modul: Städtebau und urbaner Kontext
# Dleteted 1 child modules for: Städtebau und urbaner Kontext
# Added 2 child modules for: Städtebau und urbaner Kontext
# Update existing modul: Masterarbeit
# Dleteted 1 child modules for: Masterarbeit
# Added 2 child modules for: Masterarbeit
# Update existing modul: Kolloquium
# Dleteted 1 child modules for: Kolloquium
# Added 2 child modules for: Kolloquium
# Update existing modul: Sonderthemen Städtebau
# Dleteted 2 child modules for: Sonderthemen Städtebau
# Added 2 child modules for: Sonderthemen Städtebau
# Update existing modul: Sonderthemen Stadtbaukultur
# Dleteted 1 child modules for: Sonderthemen Stadtbaukultur
# Added 2 child modules for: Sonderthemen Stadtbaukultur
# Update existing modul: Praxis der Wohn- und Quartiersentwicklung
# Dleteted 2 child modules for: Praxis der Wohn- und Quartiersentwicklung
# Added 2 child modules for: Praxis der Wohn- und Quartiersentwicklung
# Update existing modul: Praxis der Stadterneuerung
# Dleteted 1 child modules for: Praxis der Stadterneuerung
# Added 2 child modules for: Praxis der Stadterneuerung
# Update existing modul: Stadtbaukultur in Lübeck
# Dleteted 3 child modules for: Stadtbaukultur in Lübeck
# Added 2 child modules for: Stadtbaukultur in Lübeck
# Update existing modul: Urbane Transformation
# Dleteted 1 child modules for: Urbane Transformation
# Added 2 child modules for: Urbane Transformation
#  Stadtentwicklung aktuell BAU_SPM
# Modul not yet in modulhandbuch: Stadtentwicklung aktuell
# Added 2 child modules for: Stadtentwicklung aktuell
# Update existing modul: Exkursion
# Dleteted 1 child modules for: Exkursion
# Added 2 child modules for: Exkursion
# Update existing modul: Grundlagen der Gleichstromtechnik
# Dleteted 5 child modules for: Grundlagen der Gleichstromtechnik
# Added 3 child modules for: Grundlagen der Gleichstromtechnik
# Update existing modul: Mathematik I
# Dleteted 2 child modules for: Mathematik I
# Added 2 child modules for: Mathematik I
# Update existing modul: Physik
# Dleteted 1 child modules for: Physik
# Added 2 child modules for: Physik
# Update existing modul: Projekt- und Selbstmanagement
# Dleteted 2 child modules for: Projekt- und Selbstmanagement
# Added 2 child modules for: Projekt- und Selbstmanagement
# Update existing modul: Prozedurale Programmierung
# Dleteted 2 child modules for: Prozedurale Programmierung
# Added 2 child modules for: Prozedurale Programmierung
# Update existing modul: Digitaltechnik
# Dleteted 2 child modules for: Digitaltechnik
# Added 2 child modules for: Digitaltechnik
# Update existing modul: Grundlagen der Wechselstromtechnik
# Dleteted 3 child modules for: Grundlagen der Wechselstromtechnik
# Added 3 child modules for: Grundlagen der Wechselstromtechnik
# Update existing modul: Mathematik für Elektrotechniker
# Dleteted 2 child modules for: Mathematik für Elektrotechniker
# Added 2 child modules for: Mathematik für Elektrotechniker
# Update existing modul: Objektorientierte Programmierung
# Dleteted 2 child modules for: Objektorientierte Programmierung
# Added 2 child modules for: Objektorientierte Programmierung
#  Feldtheorie EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Feldtheorie
# Added 2 child modules for: Feldtheorie
# Update existing modul: Grundlagen der Bauelemente und Elektronik I
# Dleteted 3 child modules for: Grundlagen der Bauelemente und Elektronik I
# Added 3 child modules for: Grundlagen der Bauelemente und Elektronik I
# Update existing modul: Mikroprozessortechnik
# Dleteted 2 child modules for: Mikroprozessortechnik
# Added 2 child modules for: Mikroprozessortechnik
# Update existing modul: Messtechnik und Sensorik
# Dleteted 2 child modules for: Messtechnik und Sensorik
# Added 2 child modules for: Messtechnik und Sensorik
# Update existing modul: Signale und Systeme
# Dleteted 1 child modules for: Signale und Systeme
# Added 2 child modules for: Signale und Systeme
# Update existing modul: Regelungstechnik
# Dleteted 2 child modules for: Regelungstechnik
# Added 2 child modules for: Regelungstechnik
# Update existing modul: System Engineering
# Dleteted 2 child modules for: System Engineering
# Added 2 child modules for: System Engineering
# Update existing modul: Elektrische Energieversorgung
# Dleteted 2 child modules for: Elektrische Energieversorgung
# Added 2 child modules for: Elektrische Energieversorgung
# Update existing modul: Steuerungstechnik
# Dleteted 2 child modules for: Steuerungstechnik
# Added 2 child modules for: Steuerungstechnik
# Update existing modul: Analoge Elektronik
# Dleteted 2 child modules for: Analoge Elektronik
# Added 2 child modules for: Analoge Elektronik
# Update existing modul: Rechnergestützter Schaltungsentwurf
# Dleteted 2 child modules for: Rechnergestützter Schaltungsentwurf
# Added 2 child modules for: Rechnergestützter Schaltungsentwurf
# Update existing modul: Leistungselektronik
# Dleteted 2 child modules for: Leistungselektronik
# Added 2 child modules for: Leistungselektronik
# Update existing modul: Digitale Signalverarbeitung
# Dleteted 2 child modules for: Digitale Signalverarbeitung
# Added 2 child modules for: Digitale Signalverarbeitung
# Update existing modul: Kommunikationsnetze
# Dleteted 2 child modules for: Kommunikationsnetze
# Added 2 child modules for: Kommunikationsnetze
# Update existing modul: Elektrische Maschinen und Antriebe
# Dleteted 2 child modules for: Elektrische Maschinen und Antriebe
# Added 2 child modules for: Elektrische Maschinen und Antriebe
# Update existing modul: Elektromagnetische Verträglichkeit
# Dleteted 2 child modules for: Elektromagnetische Verträglichkeit
# Added 2 child modules for: Elektromagnetische Verträglichkeit
# Update existing modul: Hochfrequenztechnik
# Dleteted 2 child modules for: Hochfrequenztechnik
# Added 2 child modules for: Hochfrequenztechnik
# Update existing modul: Hardware-Entwurf
# Dleteted 2 child modules for: Hardware-Entwurf
# Added 2 child modules for: Hardware-Entwurf
# Update existing modul: Digitale Übertragungstechnik
# Dleteted 2 child modules for: Digitale Übertragungstechnik
# Added 2 child modules for: Digitale Übertragungstechnik
# Update existing modul: Eingebettete Systeme
# Dleteted 2 child modules for: Eingebettete Systeme
# Added 2 child modules for: Eingebettete Systeme
# Update existing modul: Elektrische Antriebstechnik
# Dleteted 2 child modules for: Elektrische Antriebstechnik
# Added 2 child modules for: Elektrische Antriebstechnik
# Update existing modul: Elektrische Netze und Anlagen
# Dleteted 1 child modules for: Elektrische Netze und Anlagen
# Added 2 child modules for: Elektrische Netze und Anlagen
# Update existing modul: Feldbustechnologien
# Dleteted 2 child modules for: Feldbustechnologien
# Added 2 child modules for: Feldbustechnologien
# Update existing modul: Leittechnik
# Dleteted 2 child modules for: Leittechnik
# Added 2 child modules for: Leittechnik
# Update existing modul: Regenerative Energiesysteme
# Dleteted 2 child modules for: Regenerative Energiesysteme
# Added 2 child modules for: Regenerative Energiesysteme
# Update existing modul: Hochintegrierte Schaltungen
# Dleteted 2 child modules for: Hochintegrierte Schaltungen
# Added 2 child modules for: Hochintegrierte Schaltungen
# Update existing modul: Mikrowellentechnik
# Dleteted 2 child modules for: Mikrowellentechnik
# Added 2 child modules for: Mikrowellentechnik
# Update existing modul: System Design Projekt
# Dleteted 1 child modules for: System Design Projekt
# Added 2 child modules for: System Design Projekt
# Update existing modul: Elektromobilität
# Dleteted 2 child modules for: Elektromobilität
# Added 2 child modules for: Elektromobilität
#  Gebäudeautomatisierung EI_ELE-ENE-BA
# Modul not yet in modulhandbuch: Gebäudeautomatisierung
# Added 2 child modules for: Gebäudeautomatisierung
# Update existing modul: Hochspannungstechnik
# Dleteted 2 child modules for: Hochspannungstechnik
# Added 2 child modules for: Hochspannungstechnik
# Update existing modul: Intelligente Energienetze
# Dleteted 2 child modules for: Intelligente Energienetze
# Added 2 child modules for: Intelligente Energienetze
# Update existing modul: Prozessautomatisierung
# Dleteted 2 child modules for: Prozessautomatisierung
# Added 2 child modules for: Prozessautomatisierung
# Update existing modul: Robotik
# Dleteted 2 child modules for: Robotik
# Added 2 child modules for: Robotik
# Update existing modul: Berufspraktikum mit Seminar
# Dleteted 5 child modules for: Berufspraktikum mit Seminar
# Added 2 child modules for: Berufspraktikum mit Seminar
#  Bachelorarbeit-Seminar EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Bachelorarbeit-Seminar
# Added 2 child modules for: Bachelorarbeit-Seminar
# Update existing modul: Bachelorarbeit und Kolloquium
# Dleteted 6 child modules for: Bachelorarbeit und Kolloquium
# Added 2 child modules for: Bachelorarbeit und Kolloquium
# Update existing modul: Berufspraktikum mit Seminar
# Dleteted 0 child modules for: Berufspraktikum mit Seminar
# Added 2 child modules for: Berufspraktikum mit Seminar
# Update existing modul: Hochintegrierte Schaltungen
# Dleteted 2 child modules for: Hochintegrierte Schaltungen
# Added 2 child modules for: Hochintegrierte Schaltungen
#  Stochastik EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Stochastik
# Added 2 child modules for: Stochastik
#  Technical English EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Technical English
# Added 2 child modules for: Technical English
#  Analog Electronics EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Analog Electronics
# Added 2 child modules for: Analog Electronics
#  Communications Engineering EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Communications Engineering
# Added 2 child modules for: Communications Engineering
#  Control System Basics EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Control System Basics
# Added 2 child modules for: Control System Basics
#  German Language and Culture I EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: German Language and Culture I
# Added 2 child modules for: German Language and Culture I
#  Humanities I EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Humanities I
# Added 2 child modules for: Humanities I
#  Radio Frequencies EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Radio Frequencies
# Added 2 child modules for: Radio Frequencies
#  Signals and Systems EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Signals and Systems
# Added 2 child modules for: Signals and Systems
#  Computer Aided Design EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Computer Aided Design
# Added 2 child modules for: Computer Aided Design
#  Communication Networks EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Communication Networks
# Added 2 child modules for: Communication Networks
#  Digital Control Systems EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Digital Control Systems
# Added 2 child modules for: Digital Control Systems
#  German Language and Culture II EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: German Language and Culture II
# Added 2 child modules for: German Language and Culture II
#  Humanities II EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Humanities II
# Added 2 child modules for: Humanities II
#  Microwaves EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Microwaves
# Added 2 child modules for: Microwaves
#  Renewable Energy EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Renewable Energy
# Added 2 child modules for: Renewable Energy
#  Angewandte Kryptographie EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Angewandte Kryptographie
# Added 2 child modules for: Angewandte Kryptographie
#  Computergestützte Messtechnik EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Computergestützte Messtechnik
# Added 2 child modules for: Computergestützte Messtechnik
#  Energie- und Netzwirtschaft EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Energie- und Netzwirtschaft
# Added 2 child modules for: Energie- und Netzwirtschaft
#  IT-Sicherheit EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: IT-Sicherheit
# Added 2 child modules for: IT-Sicherheit
#  Sensortechnologien EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Sensortechnologien
# Added 2 child modules for: Sensortechnologien
#  Simulationstechniken (mit MATLAB) EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Simulationstechniken (mit MATLAB)
# Added 2 child modules for: Simulationstechniken (mit MATLAB)
#  Adaptive digitale Systeme EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Adaptive digitale Systeme
# Added 2 child modules for: Adaptive digitale Systeme
#  Drahtlose Sensorsysteme EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Drahtlose Sensorsysteme
# Added 2 child modules for: Drahtlose Sensorsysteme
#  Mobile Systeme EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Mobile Systeme
# Added 2 child modules for: Mobile Systeme
#  Netzwerkmanagement EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Netzwerkmanagement
# Added 2 child modules for: Netzwerkmanagement
#  Ortung und Navigation EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Ortung und Navigation
# Added 2 child modules for: Ortung und Navigation
#  Spezielle Themen der Kommunikationssysteme EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Spezielle Themen der Kommunikationssysteme
# Added 2 child modules for: Spezielle Themen der Kommunikationssysteme
#  Spezielle Themen der Technischen Informatik EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Spezielle Themen der Technischen Informatik
# Added 2 child modules for: Spezielle Themen der Technischen Informatik
# Update existing modul: Angewandte Mathematik
# Dleteted 2 child modules for: Angewandte Mathematik
# Added 2 child modules for: Angewandte Mathematik
# Update existing modul: Datenbanken und Informationsmanagement
# Dleteted 2 child modules for: Datenbanken und Informationsmanagement
# Added 2 child modules for: Datenbanken und Informationsmanagement
# Update existing modul: Digitale Bildverarbeitung
# Dleteted 2 child modules for: Digitale Bildverarbeitung
# Added 2 child modules for: Digitale Bildverarbeitung
# Update existing modul: Digitale Regelungssysteme
# Dleteted 2 child modules for: Digitale Regelungssysteme
# Added 2 child modules for: Digitale Regelungssysteme
# Update existing modul: Mikroprozessor-Design
# Dleteted 2 child modules for: Mikroprozessor-Design
# Added 2 child modules for: Mikroprozessor-Design
# Update existing modul: Rechnungswesen und Controlling
# Dleteted 2 child modules for: Rechnungswesen und Controlling
# Added 2 child modules for: Rechnungswesen und Controlling
# Update existing modul: Brückenkurs: Automatisierungstechnik
# Dleteted 2 child modules for: Brückenkurs: Automatisierungstechnik
# Added 2 child modules for: Brückenkurs: Automatisierungstechnik
# Update existing modul: Brückenkurs: Kommunikationstechnik
# Dleteted 2 child modules for: Brückenkurs: Kommunikationstechnik
# Added 2 child modules for: Brückenkurs: Kommunikationstechnik
# Update existing modul: Business Process Management
# Dleteted 2 child modules for: Business Process Management
# Added 2 child modules for: Business Process Management
# Update existing modul: Wissenschaftliche Projektarbeit
# Dleteted 1 child modules for: Wissenschaftliche Projektarbeit
# Added 1 child modules for: Wissenschaftliche Projektarbeit
# Update existing modul: Integrated Information Systems
# Dleteted 1 child modules for: Integrated Information Systems
# Added 1 child modules for: Integrated Information Systems
# Update existing modul: Masterarbeit und Kolloquium
# Dleteted 2 child modules for: Masterarbeit und Kolloquium
# Added 2 child modules for: Masterarbeit und Kolloquium
# Update existing modul: Digital Processing of Stochastic Signals
# Dleteted 2 child modules for: Digital Processing of Stochastic Signals
# Added 2 child modules for: Digital Processing of Stochastic Signals
# Update existing modul: Human-Computer Interfaces
# Dleteted 2 child modules for: Human-Computer Interfaces
# Added 2 child modules for: Human-Computer Interfaces
# Update existing modul: Process Integration
# Dleteted 2 child modules for: Process Integration
# Added 2 child modules for: Process Integration
# Update existing modul: Process Optimization
# Dleteted 2 child modules for: Process Optimization
# Added 2 child modules for: Process Optimization
# Update existing modul: Real-Time Systems
# Dleteted 2 child modules for: Real-Time Systems
# Added 2 child modules for: Real-Time Systems
#  Drahtlose Netze für cyber-physische Systeme EI_ANG-INF-MA
# Modul not yet in modulhandbuch: Drahtlose Netze für cyber-physische Systeme
# Added 2 child modules for: Drahtlose Netze für cyber-physische Systeme
#  Hardware-basierte IT-Sicherheit EI_ANG-INF-MA
# Modul not yet in modulhandbuch: Hardware-basierte IT-Sicherheit
# Added 2 child modules for: Hardware-basierte IT-Sicherheit
#  Sichere Programmierung EI_ANG-INF-MA
# Modul not yet in modulhandbuch: Sichere Programmierung
# Added 2 child modules for: Sichere Programmierung
#  Mobile Anwendungen EI_ANG-INF-MA
# Modul not yet in modulhandbuch: Mobile Anwendungen
# Added 2 child modules for: Mobile Anwendungen
#  Sichere vernetzte Steuerungssysteme EI_ANG-INF-MA
# Modul not yet in modulhandbuch: Sichere vernetzte Steuerungssysteme
# Added 2 child modules for: Sichere vernetzte Steuerungssysteme
# Update existing modul: Grundlagen der Gleichstromtechnik
# Dleteted 5 child modules for: Grundlagen der Gleichstromtechnik
# Added 3 child modules for: Grundlagen der Gleichstromtechnik
# Update existing modul: Mathematik I
# Dleteted 2 child modules for: Mathematik I
# Added 2 child modules for: Mathematik I
# Update existing modul: Physik
# Dleteted 1 child modules for: Physik
# Added 1 child modules for: Physik
# Update existing modul: Projekt- und Selbstmanagement
# Dleteted 2 child modules for: Projekt- und Selbstmanagement
# Added 2 child modules for: Projekt- und Selbstmanagement
# Update existing modul: Prozedurale Programmierung
# Dleteted 2 child modules for: Prozedurale Programmierung
# Added 2 child modules for: Prozedurale Programmierung
# Update existing modul: Digitaltechnik
# Dleteted 2 child modules for: Digitaltechnik
# Added 2 child modules for: Digitaltechnik
# Update existing modul: Grundlagen der Wechselstromtechnik
# Dleteted 3 child modules for: Grundlagen der Wechselstromtechnik
# Added 3 child modules for: Grundlagen der Wechselstromtechnik
# Update existing modul: Mathematik für Elektrotechniker
# Dleteted 2 child modules for: Mathematik für Elektrotechniker
# Added 2 child modules for: Mathematik für Elektrotechniker
# Update existing modul: Objektorientierte Programmierung
# Dleteted 2 child modules for: Objektorientierte Programmierung
# Added 2 child modules for: Objektorientierte Programmierung
#  Feldtheorie EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Feldtheorie
# Added 1 child modules for: Feldtheorie
#  Grundlagen der Bauelemente und Elektronik I EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Grundlagen der Bauelemente und Elektronik I
# Added 3 child modules for: Grundlagen der Bauelemente und Elektronik I
# Update existing modul: Mikroprozessortechnik
# Dleteted 2 child modules for: Mikroprozessortechnik
# Added 2 child modules for: Mikroprozessortechnik
# Update existing modul: Messtechnik und Sensorik
# Dleteted 2 child modules for: Messtechnik und Sensorik
# Added 2 child modules for: Messtechnik und Sensorik
# Update existing modul: Signale und Systeme
# Dleteted 1 child modules for: Signale und Systeme
# Added 1 child modules for: Signale und Systeme
# Update existing modul: Informatik I
# Dleteted 2 child modules for: Informatik I
# Added 2 child modules for: Informatik I
# Update existing modul: Softwaretechnik I
# Dleteted 2 child modules for: Softwaretechnik I
# Added 2 child modules for: Softwaretechnik I
# Update existing modul: Digitale Signalverarbeitung
# Dleteted 2 child modules for: Digitale Signalverarbeitung
# Added 2 child modules for: Digitale Signalverarbeitung
# Update existing modul: Regelungstechnik
# Dleteted 2 child modules for: Regelungstechnik
# Added 2 child modules for: Regelungstechnik
# Update existing modul: System Engineering
# Dleteted 2 child modules for: System Engineering
# Added 2 child modules for: System Engineering
# Update existing modul: Hochintegrierte Schaltungen
# Dleteted 2 child modules for: Hochintegrierte Schaltungen
# Added 2 child modules for: Hochintegrierte Schaltungen
# Update existing modul: System Design Projekt
# Dleteted 1 child modules for: System Design Projekt
# Added 1 child modules for: System Design Projekt
# Update existing modul: Berufspraktikum mit Seminar
# Dleteted 2 child modules for: Berufspraktikum mit Seminar
# Added 1 child modules for: Berufspraktikum mit Seminar
#  Bachelorarbeit-Seminar EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Bachelorarbeit-Seminar
# Added 1 child modules for: Bachelorarbeit-Seminar
# Update existing modul: Bachelorarbeit und Kolloquium
# Dleteted 2 child modules for: Bachelorarbeit und Kolloquium
# Added 2 child modules for: Bachelorarbeit und Kolloquium
# Update existing modul: Analoge Elektronik
# Dleteted 2 child modules for: Analoge Elektronik
# Added 2 child modules for: Analoge Elektronik
# Update existing modul: Kommunikationsnetze
# Dleteted 2 child modules for: Kommunikationsnetze
# Added 2 child modules for: Kommunikationsnetze
# Update existing modul: Rechnergestützter Schaltungsentwurf
# Dleteted 2 child modules for: Rechnergestützter Schaltungsentwurf
# Added 2 child modules for: Rechnergestützter Schaltungsentwurf
# Update existing modul: Elektromagnetische Verträglichkeit
# Dleteted 2 child modules for: Elektromagnetische Verträglichkeit
# Added 2 child modules for: Elektromagnetische Verträglichkeit
# Update existing modul: Hardware-Entwurf
# Dleteted 2 child modules for: Hardware-Entwurf
# Added 2 child modules for: Hardware-Entwurf
# Update existing modul: Hochfrequenztechnik
# Dleteted 2 child modules for: Hochfrequenztechnik
# Added 2 child modules for: Hochfrequenztechnik
# Update existing modul: Digitale Übertragungstechnik
# Dleteted 2 child modules for: Digitale Übertragungstechnik
# Added 2 child modules for: Digitale Übertragungstechnik
# Update existing modul: Mikrowellentechnik
# Dleteted 2 child modules for: Mikrowellentechnik
# Added 2 child modules for: Mikrowellentechnik
# Update existing modul: Elektronik
# Dleteted 2 child modules for: Elektronik
# Added 2 child modules for: Elektronik
# Update existing modul: Informatik II
# Dleteted 2 child modules for: Informatik II
# Added 2 child modules for: Informatik II
# Update existing modul: Betriebssysteme
# Dleteted 2 child modules for: Betriebssysteme
# Added 2 child modules for: Betriebssysteme
# Update existing modul: Verteilte Systeme
# Dleteted 2 child modules for: Verteilte Systeme
# Added 2 child modules for: Verteilte Systeme
# Update existing modul: Grundlagen Webprogrammierung
# Dleteted 2 child modules for: Grundlagen Webprogrammierung
# Added 2 child modules for: Grundlagen Webprogrammierung
# Update existing modul: Berufspraktikum mit Seminar
# Dleteted 1 child modules for: Berufspraktikum mit Seminar
# Added 1 child modules for: Berufspraktikum mit Seminar
# Update existing modul: Hochintegrierte Schaltungen
# Dleteted 2 child modules for: Hochintegrierte Schaltungen
# Added 2 child modules for: Hochintegrierte Schaltungen
# Update existing modul: Stochastik
# Dleteted 2 child modules for: Stochastik
# Added 2 child modules for: Stochastik
# Update existing modul: Technical English
# Dleteted 1 child modules for: Technical English
# Added 1 child modules for: Technical English
# Update existing modul: Analog Electronics
# Dleteted 2 child modules for: Analog Electronics
# Added 2 child modules for: Analog Electronics
# Update existing modul: Communications Engineering
# Dleteted 4 child modules for: Communications Engineering
# Added 2 child modules for: Communications Engineering
# Update existing modul: Control System Basics
# Dleteted 5 child modules for: Control System Basics
# Added 2 child modules for: Control System Basics
# Update existing modul: German Language and Culture I
# Dleteted 1 child modules for: German Language and Culture I
# Added 1 child modules for: German Language and Culture I
# Update existing modul: Humanities I
# Dleteted 1 child modules for: Humanities I
# Added 1 child modules for: Humanities I
# Update existing modul: Radio Frequencies
# Dleteted 2 child modules for: Radio Frequencies
# Added 2 child modules for: Radio Frequencies
# Update existing modul: Signals and Systems
# Dleteted 1 child modules for: Signals and Systems
# Added 1 child modules for: Signals and Systems
# Update existing modul: Computer Aided Design
# Dleteted 2 child modules for: Computer Aided Design
# Added 2 child modules for: Computer Aided Design
#  Communication Networks EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Communication Networks
# Added 2 child modules for: Communication Networks
#  Digital Control Systems EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Digital Control Systems
# Added 2 child modules for: Digital Control Systems
# Update existing modul: German Language and Culture II
# Dleteted 1 child modules for: German Language and Culture II
# Added 1 child modules for: German Language and Culture II
# Update existing modul: Humanities II
# Dleteted 1 child modules for: Humanities II
# Added 1 child modules for: Humanities II
# Update existing modul: Microwaves
# Dleteted 5 child modules for: Microwaves
# Added 2 child modules for: Microwaves
#  Renewable Energy EI_ELE-KOM-BA
# Modul not yet in modulhandbuch: Renewable Energy
# Added 2 child modules for: Renewable Energy
# Update existing modul: Angewandte Kryptographie
# Dleteted 2 child modules for: Angewandte Kryptographie
# Added 2 child modules for: Angewandte Kryptographie
# ...
# Dleteted 1 child modules for: Betriebswirtschaftslehre
# Added 1 child modules for: Betriebswirtschaftslehre
# Update existing modul: Datenmanagement
# Dleteted 2 child modules for: Datenmanagement
# Added 2 child modules for: Datenmanagement
#  Softwaretechnik II EI_INF-SOF-BA
# Modul not yet in modulhandbuch: Softwaretechnik II
# Added 2 child modules for: Softwaretechnik II
# Update existing modul: Webtechnologie Projekt
# Dleteted 2 child modules for: Webtechnologie Projekt
# Added 2 child modules for: Webtechnologie Projekt
# Update existing modul: Formale Sprachen und Übersetzertechniken
# Dleteted 2 child modules for: Formale Sprachen und Übersetzertechniken
# Added 2 child modules for: Formale Sprachen und Übersetzertechniken
# Update existing modul: Intelligente Systeme
# Dleteted 2 child modules for: Intelligente Systeme
# Added 2 child modules for: Intelligente Systeme
# Update existing modul: Bachelorarbeit-Seminar
# Dleteted 1 child modules for: Bachelorarbeit-Seminar
# Added 1 child modules for: Bachelorarbeit-Seminar
# Update existing modul: Bachelorarbeit und Kolloquium
# Dleteted 4 child modules for: Bachelorarbeit und Kolloquium
# Added 2 child modules for: Bachelorarbeit und Kolloquium
# Update existing modul: Softwaretechnik-Projekt
# Dleteted 1 child modules for: Softwaretechnik-Projekt
# Added 1 child modules for: Softwaretechnik-Projekt
#  Angewandte Kryptographie EI_INF-SOF-BA
# Modul not yet in modulhandbuch: Angewandte Kryptographie
# Added 2 child modules for: Angewandte Kryptographie
# Update existing modul: Autonome Systeme
# Dleteted 2 child modules for: Autonome Systeme
# Added 2 child modules for: Autonome Systeme
#  Basiswissen Softwaretest EI_INF-SOF-BA
# Modul not yet in modulhandbuch: Basiswissen Softwaretest
# Added 2 child modules for: Basiswissen Softwaretest
# Update existing modul: Betriebssysteme Vertiefung
# Dleteted 2 child modules for: Betriebssysteme Vertiefung
# Added 2 child modules for: Betriebssysteme Vertiefung
# Update existing modul: Drahtlose Sensorsysteme
# Dleteted 2 child modules for: Drahtlose Sensorsysteme
# Added 2 child modules for: Drahtlose Sensorsysteme
# Update existing modul: Embedded Software Development
# Dleteted 2 child modules for: Embedded Software Development
# Added 2 child modules for: Embedded Software Development
# Update existing modul: Fachprojekt
# Dleteted 1 child modules for: Fachprojekt
# Added 1 child modules for: Fachprojekt
# Couldnt find program for name: (Nicht festgelegt)
# Update existing modul: Architekturen und Paradigmen verteilter Systeme
# Dleteted 2 child modules for: Architekturen und Paradigmen verteilter Systeme
# Added 2 child modules for: Architekturen und Paradigmen verteilter Systeme
# Update existing modul: Cloud-native Programmierung
# Dleteted 2 child modules for: Cloud-native Programmierung
# Added 2 child modules for: Cloud-native Programmierung
# Update existing modul: Digital Impact
# Dleteted 1 child modules for: Digital Impact
# Added 1 child modules for: Digital Impact
# Update existing modul: Sicherheit verteilter Systeme
# Dleteted 2 child modules for: Sicherheit verteilter Systeme
# Added 2 child modules for: Sicherheit verteilter Systeme
# Update existing modul: Verifikation und Konsistenzmodelle verteilter Systeme
# Dleteted 2 child modules for: Verifikation und Konsistenzmodelle verteilter Systeme
# Added 2 child modules for: Verifikation und Konsistenzmodelle verteilter Systeme
#  Verteilte Datenbank- und Informationssysteme EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Verteilte Datenbank- und Informationssysteme
# Added 2 child modules for: Verteilte Datenbank- und Informationssysteme
# Update existing modul: Cloud-native Architekturen
# Dleteted 2 child modules for: Cloud-native Architekturen
# Added 2 child modules for: Cloud-native Architekturen
#  Programmierung verteilter Systeme EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Programmierung verteilter Systeme
# Added 2 child modules for: Programmierung verteilter Systeme
# Update existing modul: Verteilte Eingebettete Systeme
# Dleteted 2 child modules for: Verteilte Eingebettete Systeme
# Added 2 child modules for: Verteilte Eingebettete Systeme
# Update existing modul: Wissenschaftliches Projekt I
# Dleteted 3 child modules for: Wissenschaftliches Projekt I
# Added 1 child modules for: Wissenschaftliches Projekt I
# Update existing modul: Wissenschaftliches Seminar
# Dleteted 1 child modules for: Wissenschaftliches Seminar
# Added 1 child modules for: Wissenschaftliches Seminar
# Update existing modul: Seminar Verteilte Systeme
# Dleteted 1 child modules for: Seminar Verteilte Systeme
# Added 1 child modules for: Seminar Verteilte Systeme
#  Sicherheit und Webanwendungen EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Sicherheit und Webanwendungen
# Unkwon Lehrveranstaltungsart of Sicherheit und Web Anwendungen (Online-Modul) Online-Lehrveranstaltung
# Added 1 child modules for: Sicherheit und Webanwendungen
#  Wissenschaftliches Projekt II EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Wissenschaftliches Projekt II
# Added 1 child modules for: Wissenschaftliches Projekt II
#  Hardware-basierte IT-Sicherheit EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Hardware-basierte IT-Sicherheit
# Added 2 child modules for: Hardware-basierte IT-Sicherheit
# Update existing modul: Human-Computer Interfaces
# Dleteted 2 child modules for: Human-Computer Interfaces
# Added 2 child modules for: Human-Computer Interfaces
# Update existing modul: Intelligente verteilte Systeme
# Dleteted 2 child modules for: Intelligente verteilte Systeme
# Added 2 child modules for: Intelligente verteilte Systeme
# Update existing modul: Kryptoanalyse
# Dleteted 2 child modules for: Kryptoanalyse
# Added 2 child modules for: Kryptoanalyse
# Update existing modul: Kryptographie
# Dleteted 5 child modules for: Kryptographie
# Added 2 child modules for: Kryptographie
# Update existing modul: Mikroprozessor-Design
# Dleteted 2 child modules for: Mikroprozessor-Design
# Added 2 child modules for: Mikroprozessor-Design
# Update existing modul: Mobile Anwendungen
# Dleteted 2 child modules for: Mobile Anwendungen
# Added 2 child modules for: Mobile Anwendungen
# Update existing modul: Real-Time Systems
# Dleteted 2 child modules for: Real-Time Systems
# Added 2 child modules for: Real-Time Systems
#  Sichere vernetzte Steuerungssysteme EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Sichere vernetzte Steuerungssysteme
# Added 2 child modules for: Sichere vernetzte Steuerungssysteme
#  Sichere Programmierung EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Sichere Programmierung
# Added 2 child modules for: Sichere Programmierung
# Update existing modul: Spezielle Themen verteilter Systeme I
# Dleteted 5 child modules for: Spezielle Themen verteilter Systeme I
# Added 2 child modules for: Spezielle Themen verteilter Systeme I
#  Spezielle Themen verteilter Systeme II EI_INF-VER-SYS-MA
# Modul not yet in modulhandbuch: Spezielle Themen verteilter Systeme II
# Added 2 child modules for: Spezielle Themen verteilter Systeme II
# Update existing modul: Berufspraktikum (Orientierung)
# Dleteted 1 child modules for: Berufspraktikum (Orientierung)
# Added 1 child modules for: Berufspraktikum (Orientierung)
# Update existing modul: Darstellungstechniken
# Dleteted 2 child modules for: Darstellungstechniken
# Added 2 child modules for: Darstellungstechniken
# Update existing modul: Datenbanken
# Dleteted 2 child modules for: Datenbanken
# Added 2 child modules for: Datenbanken
# Update existing modul: Grundlagen der Programmierung
# Dleteted 2 child modules for: Grundlagen der Programmierung
# Added 2 child modules for: Grundlagen der Programmierung
# Update existing modul: Mathematische Naturwissenschaftliche Grundlagen I
# Dleteted 5 child modules for: Mathematische Naturwissenschaftliche Grundlagen I
# Added 2 child modules for: Mathematische Naturwissenschaftliche Grundlagen I
# Update existing modul: Medientheorie
# Dleteted 1 child modules for: Medientheorie
# Added 1 child modules for: Medientheorie
# Update existing modul: Digitale Systeme
# Dleteted 2 child modules for: Digitale Systeme
# Added 2 child modules for: Digitale Systeme
# Update existing modul: EBV / Fotografie
# Dleteted 2 child modules for: EBV / Fotografie
# Added 2 child modules for: EBV / Fotografie
#  Mathematische Naturwissenschaftliche Grundlagen II EI_INF-DES-BA
# Modul not yet in modulhandbuch: Mathematische Naturwissenschaftliche Grundlagen II
# Added 2 child modules for: Mathematische Naturwissenschaftliche Grundlagen II
# Update existing modul: Vertiefung Programmierung
# Dleteted 2 child modules for: Vertiefung Programmierung
# Added 2 child modules for: Vertiefung Programmierung
# Update existing modul: Softwaretechnik
# Dleteted 4 child modules for: Softwaretechnik
# Added 2 child modules for: Softwaretechnik
# Update existing modul: 3D-Animation und Video-Compositing
# Dleteted 2 child modules for: 3D-Animation und Video-Compositing
# Added 2 child modules for: 3D-Animation und Video-Compositing
# Update existing modul: Designpsychologie
# Dleteted 2 child modules for: Designpsychologie
# Added 2 child modules for: Designpsychologie
# Update existing modul: Digitale Verfahren
# Dleteted 2 child modules for: Digitale Verfahren
# Added 2 child modules for: Digitale Verfahren
# Update existing modul: Konzeption interaktiver Medien
# Dleteted 1 child modules for: Konzeption interaktiver Medien
# Added 1 child modules for: Konzeption interaktiver Medien
# Update existing modul: Responsive Webdesign
# Dleteted 2 child modules for: Responsive Webdesign
# Added 2 child modules for: Responsive Webdesign
# Update existing modul: Computernetze
# Dleteted 2 child modules for: Computernetze
# Added 2 child modules for: Computernetze
# Update existing modul: Grundlagen Webprogrammierung
# Dleteted 2 child modules for: Grundlagen Webprogrammierung
# Added 2 child modules for: Grundlagen Webprogrammierung
# Update existing modul: Vertiefung Webprogrammierung
# Dleteted 2 child modules for: Vertiefung Webprogrammierung
# Added 2 child modules for: Vertiefung Webprogrammierung
# Update existing modul: Betriebswirtschaftslehre
# Dleteted 1 child modules for: Betriebswirtschaftslehre
# Added 1 child modules for: Betriebswirtschaftslehre
# Update existing modul: Berufspraktikum (Präsentation)
# Dleteted 1 child modules for: Berufspraktikum (Präsentation)
# Added 1 child modules for: Berufspraktikum (Präsentation)
# Update existing modul: Gründungsmanagement
# Dleteted 1 child modules for: Gründungsmanagement
# Unkwon Lehrveranstaltungsart of Gründungsmanagement Online-Lehrveranstaltung
# Added 1 child modules for: Gründungsmanagement
# Update existing modul: IT-Recht
# Dleteted 1 child modules for: IT-Recht
# Unkwon Lehrveranstaltungsart of IT-Recht Online-Lehrveranstaltung
# Added 1 child modules for: IT-Recht
# Update existing modul: Bachelorarbeit und Kolloquium
# Dleteted 4 child modules for: Bachelorarbeit und Kolloquium
# Added 2 child modules for: Bachelorarbeit und Kolloquium
# Update existing modul: Filmgestaltung
# Dleteted 4 child modules for: Filmgestaltung
# Added 2 child modules for: Filmgestaltung
# Update existing modul: Stereografie und Immersive Medien
# Dleteted 4 child modules for: Stereografie und Immersive Medien
# Added 2 child modules for: Stereografie und Immersive Medien
# Update existing modul: Audiotechnik und Sounddesign
# Dleteted 4 child modules for: Audiotechnik und Sounddesign
# Added 2 child modules for: Audiotechnik und Sounddesign
# Update existing modul: Designprojekt I (CDE)
# Dleteted 1 child modules for: Designprojekt I (CDE)
# Added 1 child modules for: Designprojekt I (CDE)
# Update existing modul: Designprojekt II (CDE)
# Dleteted 1 child modules for: Designprojekt II (CDE)
# Added 1 child modules for: Designprojekt II (CDE)
# Update existing modul: Transmedia
# Dleteted 2 child modules for: Transmedia
# Added 2 child modules for: Transmedia
# Update existing modul: Designmethodologie
# Dleteted 2 child modules for: Designmethodologie
# Added 2 child modules for: Designmethodologie
# Update existing modul: Usability / User Experience Design
# Dleteted 4 child modules for: Usability / User Experience Design
# Added 2 child modules for: Usability / User Experience Design
# Update existing modul: Designprojekt I (HCD)
# Dleteted 1 child modules for: Designprojekt I (HCD)
# Added 1 child modules for: Designprojekt I (HCD)
# Update existing modul: Interaktionsdesign
# Dleteted 2 child modules for: Interaktionsdesign
# Added 1 child modules for: Interaktionsdesign
# Update existing modul: Kooperationssysteme und Social Media
# Dleteted 2 child modules for: Kooperationssysteme und Social Media
# Added 2 child modules for: Kooperationssysteme und Social Media
# Update existing modul: Designprojekt II (HCD)
# Dleteted 1 child modules for: Designprojekt II (HCD)
# Added 1 child modules for: Designprojekt II (HCD)
# Update existing modul: Design Research: Methoden und Szenarien
# Dleteted 2 child modules for: Design Research: Methoden und Szenarien
# Added 1 child modules for: Design Research: Methoden und Szenarien
# Update existing modul: Design Research: Methoden und Szenarien
# Dleteted 1 child modules for: Design Research: Methoden und Szenarien
# Added 1 child modules for: Design Research: Methoden und Szenarien
# Update existing modul: Interaktionsdesign
# Dleteted 1 child modules for: Interaktionsdesign
# Added 1 child modules for: Interaktionsdesign
# Update existing modul: Kooperationssysteme und Social Media
# Dleteted 2 child modules for: Kooperationssysteme und Social Media
# Added 2 child modules for: Kooperationssysteme und Social Media
# Update existing modul: Usability / User Experience Design
# Dleteted 2 child modules for: Usability / User Experience Design
# Added 2 child modules for: Usability / User Experience Design
# Update existing modul: Audiotechnik und Sounddesign
# Dleteted 2 child modules for: Audiotechnik und Sounddesign
# Added 2 child modules for: Audiotechnik und Sounddesign
# Update existing modul: Filmgestaltung Vertiefung
# Dleteted 2 child modules for: Filmgestaltung Vertiefung
# Added 2 child modules for: Filmgestaltung Vertiefung
# Update existing modul: Stereografie und Immersive Medien
# Dleteted 2 child modules for: Stereografie und Immersive Medien
# Added 2 child modules for: Stereografie und Immersive Medien
# Update existing modul: 2DGame-Prototyping
# Dleteted 2 child modules for: 2DGame-Prototyping
# Added 2 child modules for: 2DGame-Prototyping
# Update existing modul: 3D Game Prototyping
# Dleteted 2 child modules for: 3D Game Prototyping
# Added 2 child modules for: 3D Game Prototyping
# Update existing modul: Ästhetik
# Dleteted 1 child modules for: Ästhetik
# Added 1 child modules for: Ästhetik
# Update existing modul: Design von 3D-Nutzeroberflächen
# Dleteted 1 child modules for: Design von 3D-Nutzeroberflächen
# Added 1 child modules for: Design von 3D-Nutzeroberflächen
# Update existing modul: Filmgestaltung
# Dleteted 2 child modules for: Filmgestaltung
# Added 2 child modules for: Filmgestaltung
# Update existing modul: Fotografie Vertiefung
# Dleteted 2 child modules for: Fotografie Vertiefung
# Added 2 child modules for: Fotografie Vertiefung
# Update existing modul: Grundlagen der Typographie
# Dleteted 1 child modules for: Grundlagen der Typographie
# Added 1 child modules for: Grundlagen der Typographie
# Update existing modul: Serielle Bildprozesse
# Dleteted 1 child modules for: Serielle Bildprozesse
# Added 1 child modules for: Serielle Bildprozesse
# Update existing modul: Spezielle Themen der Medienwissenschaften I
# Dleteted 4 child modules for: Spezielle Themen der Medienwissenschaften I
# Added 2 child modules for: Spezielle Themen der Medienwissenschaften I
# Update existing modul: Spezielle Themen der Medienwissenschaften II
# Dleteted 0 child modules for: Spezielle Themen der Medienwissenschaften II
# Added 2 child modules for: Spezielle Themen der Medienwissenschaften II
# Update existing modul: Storyboarding und dessen Umsetzung
# Dleteted 1 child modules for: Storyboarding und dessen Umsetzung
# Added 1 child modules for: Storyboarding und dessen Umsetzung
# Update existing modul: Visual Effects
# Dleteted 2 child modules for: Visual Effects
# Added 2 child modules for: Visual Effects
# Update existing modul: Visuelle Musik
# Dleteted 2 child modules for: Visuelle Musik
# Added 2 child modules for: Visuelle Musik

# %%
modulhandbuch.toCsv()
